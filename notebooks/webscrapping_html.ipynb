# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import os
import re

# %% [markdown]
# ## Scrapping sobre el HTML de Idealista (Manises y alrededores)

# %% [markdown]
# Primera pagina: https://www.idealista.com/areas/venta-viviendas/pagina-10?shape=%28%28__%7DoFb%7DiBehHu%7EBaxCs_HjhI%7D_JlbEjiCdQjuDw%7BAn_M%29%29

# %% [markdown]
# ### Primero comprobamos que BeautifulSoup funciona con uno de los ficheros de Idealista

# %%
# Leer el archivo HTML
with open('../data/raw/idealista/idealista1.txt', 'r', encoding='utf-8') as file:
    html_content = file.read()

# Analizar el contenido HTML de una forma estructurada y fácil de manipular.
soup = bs(html_content, "lxml") # Parser LXML

# Usar select para buscar el elemento <main>
main_content = soup.select('main.listing-items.core-vitals-listing-map#main-content')

# Buscar todos los <div class="item-info-container"> dentro de main_content
item_info_containers = main_content[0].select('div.item-info-container')

# Mostrar la información de cada elemento encontrado
for i, container in enumerate(item_info_containers, start=1):
    print(f"Elemento {i}:\n")
    print(container.prettify())
    print("\n" + "="*50 + "\n")
# Out:
# Elemento 1:
#
# <div class="item-info-container">
#  <a aria-level="2" class="item-link" href="/inmueble/84855858/" role="heading" title="Piso en calle Major, 183, El Mercado, Manises">
#   Piso en calle Major, 183, El Mercado, Manises
#  </a>
#  <div class="price-row">
#   <span class="item-price h2-simulated">
#    160.000
#    <span class="txt-big">
#     €
#    </span>
#   </span>
#  </div>
#  <div class="item-detail-char">
#   <span class="item-detail">
#    3 hab.
#   </span>
#   <span class="item-detail">
#    95 m²
#   </span>
#   <span class="item-detail">
#    Planta 2ª exterior con ascensor
#   </span>
#  </div>
#  <div class="item-description description">
#   <p class="ellipsis">
#    NEGOCIABLES
# Vendo piso en muy buena zona, 81m muy bien distribuidos, 3 habitaciones 2 de ellas de matrimonio y otra un poco más pequeña, baño con bañera y un aseo de cortesía, comedor, cocina, balcón y galeria. Es un 2 con ascensor, muy bien cuidado y en perfectas condiciones.
#   </p>
#  </div>
#  <div class="item-toolbar">
#   <button class="icon-chat email-btn action-email fake-anchor" type="button">
#    <span>
#     Contactar
#    </span>
#   </button>
#   <button aria-label="contact phone" class="icon-phone phone-btn hidden-contact-phones_link item-clickable-phone fake-anchor" type="button">
#    <span class="hidden-contact-phones_text">
#     Llamar
#    </span>
#    <span class="animation_circle">
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#    </span>
#   </button>
#   <button aria-label="contact phone" class="icon-phone hidden-contact-phones_link see-phones-btn fake-anchor" type="button">
#    <span class="hidden-contact-phones_text">
#     Ver teléfono
#    </span>
#    <span class="animation_circle">
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#    </span>
#   </button>
#   <button class="trash-btn icon-trash-outline --old action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow" title="Descartar" type="button">
#    <span>
#     Descartar
#    </span>
#   </button>
#   <button class="icon-no-fav --old favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Favorito" title="Guardar" type="button">
#    <span>
#     Guardar
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 2:
#
# <div class="item-info-container">
#  <a aria-level="2" class="item-link" href="/inmueble/104674795/" role="heading" title="Ático en calle Penyal d'Ifach, 10, Aldaia">
#   Ático en calle Penyal d'Ifach, 10, Aldaia
#  </a>
#  <div class="price-row">
#   <span class="item-price h2-simulated">
#    190.000
#    <span class="txt-big">
#     €
#    </span>
#   </span>
#  </div>
#  <div class="item-detail-char">
#   <span class="item-detail">
#    3 hab.
#   </span>
#   <span class="item-detail">
#    150 m²
#   </span>
#   <span class="item-detail">
#    Planta 3ª exterior con ascensor
#   </span>
#  </div>
#  <div class="item-description description">
#  </div>
#  <div class="item-toolbar">
#   <button class="icon-chat email-btn action-email fake-anchor" type="button">
#    <span>
#     Contactar
#    </span>
#   </button>
#   <button aria-label="contact phone" class="icon-phone phone-btn hidden-contact-phones_link item-clickable-phone fake-anchor" type="button">
#    <span class="hidden-contact-phones_text">
#     Llamar
#    </span>
#    <span class="animation_circle">
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#    </span>
#   </button>
#   <button aria-label="contact phone" class="icon-phone hidden-contact-phones_link see-phones-btn fake-anchor" type="button">
#    <span class="hidden-contact-phones_text">
#     Ver teléfono
#    </span>
#    <span class="animation_circle">
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#    </span>
#   </button>
#   <button class="trash-btn icon-trash-outline --old action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow" title="Descartar" type="button">
#    <span>
#     Descartar
#    </span>
#   </button>
#   <button class="icon-no-fav --old favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Favorito" title="Guardar" type="button">
#    <span>
#     Guardar
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 3:
#
# <div class="item-info-container">
#  <a aria-level="2" class="item-link" href="/inmueble/102913892/" role="heading" title="Casa o chalet independiente en Aldaia">
#   Casa o chalet independiente en Aldaia
#  </a>
#  <div class="price-row">
#   <span class="item-price h2-simulated">
#    265.000
#    <span class="txt-big">
#     €
#    </span>
#   </span>
#  </div>
#  <div class="item-detail-char">
#   <span class="item-detail">
#    1 hab.
#   </span>
#   <span class="item-detail">
#    550 m²
#   </span>
#  </div>
#  <div class="item-description description">
#   <p class="ellipsis">
#    Situada en calle céntrica de Aldaia con una superficie de 385 m2 y 16 metros de fachada. Una casa para rehabilitar, con carácter que puedes modelar a tu gusto ¿por qué no comprar una casa de segunda mano e impregnarla con la esencia y el estilo que te gusta? . En un entorno excepcional con todos los servicios cerca.! V
#   </p>
#  </div>
#  <div class="item-toolbar">
#   <button class="icon-chat email-btn action-email fake-anchor" type="button">
#    <span>
#     Contactar
#    </span>
#   </button>
#   <button aria-label="contact phone" class="icon-phone phone-btn hidden-contact-phones_link item-clickable-phone fake-anchor" type="button">
#    <span class="hidden-contact-phones_text">
#     Llamar
#    </span>
#    <span class="animation_circle">
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#    </span>
#   </button>
#   <button aria-label="contact phone" class="icon-phone hidden-contact-phones_link see-phones-btn fake-anchor" type="button">
#    <span class="hidden-contact-phones_text">
#     Ver teléfono
#    </span>
#    <span class="animation_circle">
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#    </span>
#   </button>
#   <button class="trash-btn icon-trash-outline --old action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow" title="Descartar" type="button">
#    <span>
#     Descartar
#    </span>
#   </button>
#   <button class="icon-no-fav --old favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Favorito" title="Guardar" type="button">
#    <span>
#     Guardar
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 4:
#
# <div class="item-info-container">
#  <a aria-level="2" class="item-link" href="/inmueble/103038790/" role="heading" title="Piso en calle Joan XXIII, 9, Aldaia">
#   Piso en calle Joan XXIII, 9, Aldaia
#  </a>
#  <div class="price-row">
#   <span class="item-price h2-simulated">
#    95.000
#    <span class="txt-big">
#     €
#    </span>
#   </span>
#  </div>
#  <div class="item-detail-char">
#   <span class="item-detail">
#    3 hab.
#   </span>
#   <span class="item-detail">
#    111 m²
#   </span>
#   <span class="item-detail">
#    Planta 1ª exterior sin ascensor
#   </span>
#  </div>
#  <div class="item-description description">
#  </div>
#  <div class="item-toolbar">
#   <button class="icon-chat email-btn action-email fake-anchor" type="button">
#    <span>
#     Contactar
#    </span>
#   </button>
#   <button aria-label="contact phone" class="icon-phone phone-btn hidden-contact-phones_link item-clickable-phone fake-anchor" type="button">
#    <span class="hidden-contact-phones_text">
#     Llamar
#    </span>
#    <span class="animation_circle">
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#    </span>
#   </button>
#   <button aria-label="contact phone" class="icon-phone hidden-contact-phones_link see-phones-btn fake-anchor" type="button">
#    <span class="hidden-contact-phones_text">
#     Ver teléfono
#    </span>
#    <span class="animation_circle">
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#    </span>
#   </button>
#   <button class="trash-btn icon-trash-outline --old action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow" title="Descartar" type="button">
#    <span>
#     Descartar
#    </span>
#   </button>
#   <button class="icon-no-fav --old favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Favorito" title="Guardar" type="button">
#    <span>
#     Guardar
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 5:
#
# <div class="item-info-container">
#  <a aria-level="2" class="item-link" href="/inmueble/106075375/" role="heading" title="Casa o chalet independiente en valencia la Vella, 46, Riba-Roja de Túria">
#   Casa o chalet independiente en valencia la Vella, 46, Riba-Roja de Túria
#  </a>
#  <div class="price-row">
#   <span class="item-price h2-simulated">
#    275.000
#    <span class="txt-big">
#     €
#    </span>
#   </span>
#   <span class="item-parking">
#    Garaje incluido
#   </span>
#  </div>
#  <div class="item-detail-char">
#   <span class="item-detail">
#    3 hab.
#   </span>
#   <span class="item-detail">
#    110 m²
#   </span>
#  </div>
#  <div class="item-description description">
#  </div>
#  <div class="listing-tags-container">
#   <span class="listing-tags">
#    Alquilada
#   </span>
#  </div>
#  <div class="item-toolbar">
#   <button class="icon-chat email-btn action-email fake-anchor" type="button">
#    <span>
#     Contactar
#    </span>
#   </button>
#   <button class="trash-btn icon-trash-outline --old action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow" title="Descartar" type="button">
#    <span>
#     Descartar
#    </span>
#   </button>
#   <button class="icon-no-fav --old favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Favorito" title="Guardar" type="button">
#    <span>
#     Guardar
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 6:
#
# <div class="item-info-container">
#  <a aria-level="2" class="item-link" href="/inmueble/106862045/" role="heading" title="Piso en calle Roger de Flor, Quart de Poblet">
#   Piso en calle Roger de Flor, Quart de Poblet
#  </a>
#  <div class="price-row">
#   <span class="item-price h2-simulated">
#    93.000
#    <span class="txt-big">
#     €
#    </span>
#   </span>
#  </div>
#  <div class="item-detail-char">
#   <span class="item-detail">
#    3 hab.
#   </span>
#   <span class="item-detail">
#    91 m²
#   </span>
#   <span class="item-detail">
#    Bajo exterior sin ascensor
#   </span>
#  </div>
#  <div class="item-description description">
#   <p class="ellipsis">
#    OPORTUNIDAD INMUEBLE SIN POSESIÓN, NO SE PUEDE VISITAR. PROPIO PARA INVERSORES O VECINOS QUE CONOZCAN EL INMUEBLE.
# DISPONEMOS DE UNA AMPLIA CARTERA DE INMUEBLES SIN POSESIÓN EN VALENCIA Y EN TODA ESPAÑA.
# PROPIO, PEQUEÑO Y GRAN INVERSOR.
# La Comunidad Valenciana (oficialmente en valenciano: Comunitat Valenciana) es una
#   </p>
#  </div>
#  <div class="item-toolbar">
#   <button class="icon-chat email-btn action-email fake-anchor" type="button">
#    <span>
#     Contactar
#    </span>
#   </button>
#   <button aria-label="contact phone" class="icon-phone phone-btn hidden-contact-phones_link item-clickable-phone fake-anchor" type="button">
#    <span class="hidden-contact-phones_text">
#     Llamar
#    </span>
#    <span class="animation_circle">
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#    </span>
#   </button>
#   <button aria-label="contact phone" class="icon-phone hidden-contact-phones_link see-phones-btn fake-anchor" type="button">
#    <span class="hidden-contact-phones_text">
#     Ver teléfono
#    </span>
#    <span class="animation_circle">
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#    </span>
#   </button>
#   <button class="trash-btn icon-trash-outline --old action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow" title="Descartar" type="button">
#    <span>
#     Descartar
#    </span>
#   </button>
#   <button class="icon-no-fav --old favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Favorito" title="Guardar" type="button">
#    <span>
#     Guardar
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 7:
#
# <div class="item-info-container">
#  <picture class="logo-branding">
#   <a data-click="1" data-markup="listado::logo-agencia" href="/pro/agorainmobiliaria1/" title="Ágora inmobiliaria">
#    <img alt="Ágora inmobiliaria" loading="lazy" src="https://st3.idealista.com/9a/d2/62/agorainmobiliaria1.gif"/>
#   </a>
#  </picture>
#  <a aria-level="2" class="item-link" href="/inmueble/104689276/" role="heading" title="Dúplex en calle Penyal d'Ifach, Aldaia">
#   Dúplex en calle Penyal d'Ifach, Aldaia
#  </a>
#  <div class="price-row">
#   <span class="item-price h2-simulated">
#    190.000
#    <span class="txt-big">
#     €
#    </span>
#   </span>
#  </div>
#  <div class="item-detail-char">
#   <span class="item-detail">
#    3 hab.
#   </span>
#   <span class="item-detail">
#    150 m²
#   </span>
#   <span class="item-detail">
#    Planta 3ª exterior con ascensor
#   </span>
#  </div>
#  <div class="item-description description">
#   <p class="ellipsis">
#    ***INMOBILIARIA ÁGORA PRESENTA INCREIBLE DÚPLEX EN ALDAIA***
# REF 994
# ¡Bienvenido al hogar de tus sueños en Aldaia!
# Esta impresionante vivienda dúplex, ubicada en una tercera altura con ascensor, ofrece una combinación perfecta de comodidad, estilo y ubicación privilegiada. Con 150 metros cuadrados de espacio habitab
#   </p>
#  </div>
#  <div class="item-toolbar">
#   <button class="icon-chat email-btn action-email fake-anchor" type="button">
#    <span>
#     Contactar
#    </span>
#   </button>
#   <button aria-label="contact phone" class="icon-phone phone-btn hidden-contact-phones_link item-clickable-phone fake-anchor" type="button">
#    <span class="hidden-contact-phones_text">
#     Llamar
#    </span>
#    <span class="animation_circle">
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#    </span>
#   </button>
#   <button aria-label="contact phone" class="icon-phone hidden-contact-phones_link see-phones-btn fake-anchor" type="button">
#    <span class="hidden-contact-phones_text">
#     Ver teléfono
#    </span>
#    <span class="animation_circle">
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#    </span>
#   </button>
#   <button class="trash-btn icon-trash-outline --old action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow" title="Descartar" type="button">
#    <span>
#     Descartar
#    </span>
#   </button>
#   <button class="icon-no-fav --old favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Favorito" title="Guardar" type="button">
#    <span>
#     Guardar
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 8:
#
# <div class="item-info-container">
#  <a aria-level="2" class="item-link" href="/inmueble/106762269/" role="heading" title="Ático en calle Penyal d'Ifach, s/n, Aldaia">
#   Ático en calle Penyal d'Ifach, s/n, Aldaia
#  </a>
#  <div class="price-row">
#   <span class="item-price h2-simulated">
#    190.000
#    <span class="txt-big">
#     €
#    </span>
#   </span>
#  </div>
#  <div class="item-detail-char">
#   <span class="item-detail">
#    3 hab.
#   </span>
#   <span class="item-detail">
#    150 m²
#   </span>
#   <span class="item-detail">
#    Planta 2ª exterior con ascensor
#   </span>
#  </div>
#  <div class="item-description description">
#   <p class="ellipsis">
#    ¡Descubre el encanto de vivir en un exclusivo ático en Aldaia! Este magnífico espacio de 150 m², con 90 m² útiles, te ofrece la combinación perfecta de comodidad y estilo. Con 3 dormitorios, incluyendo una habitación doble y dos individuales, y 2 baños completos, es ideal para familias o aquellos que buscan un hogar es
#   </p>
#  </div>
#  <div class="item-toolbar">
#   <button class="icon-chat email-btn action-email fake-anchor" type="button">
#    <span>
#     Contactar
#    </span>
#   </button>
#   <button aria-label="contact phone" class="icon-phone phone-btn hidden-contact-phones_link item-clickable-phone fake-anchor" type="button">
#    <span class="hidden-contact-phones_text">
#     Llamar
#    </span>
#    <span class="animation_circle">
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#    </span>
#   </button>
#   <button aria-label="contact phone" class="icon-phone hidden-contact-phones_link see-phones-btn fake-anchor" type="button">
#    <span class="hidden-contact-phones_text">
#     Ver teléfono
#    </span>
#    <span class="animation_circle">
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#    </span>
#   </button>
#   <button class="trash-btn icon-trash-outline --old action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow" title="Descartar" type="button">
#    <span>
#     Descartar
#    </span>
#   </button>
#   <button class="icon-no-fav --old favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Favorito" title="Guardar" type="button">
#    <span>
#     Guardar
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 9:
#
# <div class="item-info-container">
#  <a aria-level="2" class="item-link" href="/inmueble/103240995/" role="heading" title="Casa o chalet independiente en calle 415, 10, La Cañada, Paterna">
#   Casa o chalet independiente en calle 415, 10, La Cañada, Paterna
#  </a>
#  <div class="price-row">
#   <span class="item-price h2-simulated">
#    400.000
#    <span class="txt-big">
#     €
#    </span>
#   </span>
#  </div>
#  <div class="item-detail-char">
#   <span class="item-detail">
#    3 hab.
#   </span>
#   <span class="item-detail">
#    255 m²
#   </span>
#  </div>
#  <div class="item-description description">
#   <p class="ellipsis">
#    (La direccion es aproximada, no es la real) NO INMOBILIARIAS
# Tiene 255 m2. Está repartida en tres plantas y tiene un semisótano. En la planta de abajo, hay un salón-comedor bastante grande y la cocina está integrada con una isla chula en medio. Además, hay salida directa al jardín, que son 168 metros cuadrados, ¡no e
#   </p>
#  </div>
#  <div class="item-toolbar">
#   <button class="icon-chat email-btn action-email fake-anchor" type="button">
#    <span>
#     Contactar
#    </span>
#   </button>
#   <button class="trash-btn icon-trash-outline --old action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow" title="Descartar" type="button">
#    <span>
#     Descartar
#    </span>
#   </button>
#   <button class="icon-no-fav --old favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Favorito" title="Guardar" type="button">
#    <span>
#     Guardar
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 10:
#
# <div class="item-info-container">
#  <a aria-level="2" class="item-link" href="/inmueble/104849444/" role="heading" title="Piso en avenida Sant Onofre, 48, Quart de Poblet">
#   Piso en avenida Sant Onofre, 48, Quart de Poblet
#  </a>
#  <div class="price-row">
#   <span class="item-price h2-simulated">
#    83.000
#    <span class="txt-big">
#     €
#    </span>
#   </span>
#  </div>
#  <div class="item-detail-char">
#   <span class="item-detail">
#    3 hab.
#   </span>
#   <span class="item-detail">
#    90 m²
#   </span>
#   <span class="item-detail">
#    Planta 5ª exterior sin ascensor
#   </span>
#  </div>
#  <div class="item-description description">
#   <p class="ellipsis">
#    Ubicación:  Quart de Poblet, a sólo 13 minutos en metro del centro de Valencia.
# Está en alquiler en este momento.
# Características del piso:
# - 3 habitaciones.
# - 1 baño.
# - 5º piso sin ascensor.
# - Totalmente reformado.
# Este apartamento es una excelente oportunidad para aquellos que buscan una vivienda en una zona t
#   </p>
#  </div>
#  <div class="item-toolbar">
#   <button class="icon-chat email-btn action-email fake-anchor" type="button">
#    <span>
#     Contactar
#    </span>
#   </button>
#   <button class="trash-btn icon-trash-outline --old action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow" title="Descartar" type="button">
#    <span>
#     Descartar
#    </span>
#   </button>
#   <button class="icon-no-fav --old favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Favorito" title="Guardar" type="button">
#    <span>
#     Guardar
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 11:
#
# <div class="item-info-container">
#  <a aria-level="2" class="item-link" href="/inmueble/102887718/" role="heading" title="Chalet adosado en calle Santa Rita, 1, Aldaia">
#   Chalet adosado en calle Santa Rita, 1, Aldaia
#  </a>
#  <div class="price-row">
#   <span class="item-price h2-simulated">
#    240.000
#    <span class="txt-big">
#     €
#    </span>
#   </span>
#   <span class="item-parking">
#    Garaje incluido
#   </span>
#  </div>
#  <div class="item-detail-char">
#   <span class="item-detail">
#    4 hab.
#   </span>
#   <span class="item-detail">
#    175 m²
#   </span>
#  </div>
#  <div class="item-description description">
#   <p class="ellipsis">
#    ¡SIN COMISIONES! Particular vende este espectacular adosado con chimenea de tres plantas ubicadas en Aldaia. Con una distribución cuidadosamente planificada, este inmueble de 175m2 ofrece comodidad y estilo en cada rincón. Plaza de garaje para 2 coches, rejas en todas las ventanas, chimenea en el piso de abajo, aire ac
#   </p>
#  </div>
#  <div class="item-toolbar">
#   <button class="icon-chat email-btn action-email fake-anchor" type="button">
#    <span>
#     Contactar
#    </span>
#   </button>
#   <button aria-label="contact phone" class="icon-phone phone-btn hidden-contact-phones_link item-clickable-phone fake-anchor" type="button">
#    <span class="hidden-contact-phones_text">
#     Llamar
#    </span>
#    <span class="animation_circle">
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#    </span>
#   </button>
#   <button aria-label="contact phone" class="icon-phone hidden-contact-phones_link see-phones-btn fake-anchor" type="button">
#    <span class="hidden-contact-phones_text">
#     Ver teléfono
#    </span>
#    <span class="animation_circle">
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#    </span>
#   </button>
#   <button class="trash-btn icon-trash-outline --old action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow" title="Descartar" type="button">
#    <span>
#     Descartar
#    </span>
#   </button>
#   <button class="icon-no-fav --old favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Favorito" title="Guardar" type="button">
#    <span>
#     Guardar
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 12:
#
# <div class="item-info-container">
#  <a aria-level="2" class="item-link" href="/inmueble/104701908/" role="heading" title="Casa o chalet independiente en calle 117, 3, La Cañada, Paterna">
#   Casa o chalet independiente en calle 117, 3, La Cañada, Paterna
#  </a>
#  <div class="price-row">
#   <span class="item-price h2-simulated">
#    690.000
#    <span class="txt-big">
#     €
#    </span>
#   </span>
#  </div>
#  <div class="item-detail-char">
#   <span class="item-detail">
#    3 hab.
#   </span>
#   <span class="item-detail">
#    120 m²
#   </span>
#  </div>
#  <div class="item-description description">
#   <p class="ellipsis">
#    Se vende chalet de una planta en perfectas condiciones, con armarios empotrados, mucha luz, cocina amueblada, puertas nuevas, en maravillosa zona residencial, con todos los servicios cerca.
#   </p>
#  </div>
#  <div class="item-toolbar">
#   <button class="icon-chat email-btn action-email fake-anchor" type="button">
#    <span>
#     Contactar
#    </span>
#   </button>
#   <button class="trash-btn icon-trash-outline --old action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow" title="Descartar" type="button">
#    <span>
#     Descartar
#    </span>
#   </button>
#   <button class="icon-no-fav --old favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Favorito" title="Guardar" type="button">
#    <span>
#     Guardar
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 13:
#
# <div class="item-info-container">
#  <a aria-level="2" class="item-link" href="/inmueble/104739045/" role="heading" title="Casa o chalet independiente en calle 577, 12, La Cañada, Paterna">
#   Casa o chalet independiente en calle 577, 12, La Cañada, Paterna
#  </a>
#  <div class="price-row">
#   <span class="item-price h2-simulated">
#    679.900
#    <span class="txt-big">
#     €
#    </span>
#   </span>
#  </div>
#  <div class="item-detail-char">
#   <span class="item-detail">
#    3 hab.
#   </span>
#   <span class="item-detail">
#    115 m²
#   </span>
#  </div>
#  <div class="item-description description">
#   <p class="ellipsis">
#    Se vende chalet unifamiliar, en zona inmejorable. Dispone de dos plantas, tres habitaciones, dos baño. Zona escolar, con supermercados y ocio cerca.
#   </p>
#  </div>
#  <div class="item-toolbar">
#   <button class="icon-chat email-btn action-email fake-anchor" type="button">
#    <span>
#     Contactar
#    </span>
#   </button>
#   <button class="trash-btn icon-trash-outline --old action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow" title="Descartar" type="button">
#    <span>
#     Descartar
#    </span>
#   </button>
#   <button class="icon-no-fav --old favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Favorito" title="Guardar" type="button">
#    <span>
#     Guardar
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 14:
#
# <div class="item-info-container">
#  <a aria-level="2" class="item-link" href="/inmueble/102258553/" role="heading" title="Casa de pueblo en calle Major, 46, Centro Ciudad, Manises">
#   Casa de pueblo en calle Major, 46, Centro Ciudad, Manises
#  </a>
#  <div class="price-row">
#   <span class="item-price h2-simulated">
#    125.000
#    <span class="txt-big">
#     €
#    </span>
#   </span>
#  </div>
#  <div class="item-detail-char">
#   <span class="item-detail">
#    3 hab.
#   </span>
#   <span class="item-detail">
#    194 m²
#   </span>
#  </div>
#  <div class="item-description description">
#   <p class="ellipsis">
#    Para reforma completa o derribo y construcción desde cero.
# Planta baja 2 locales comerciales y primera planta vivienda.
#   </p>
#  </div>
#  <div class="item-toolbar">
#   <button aria-label="contact phone" class="icon-phone phone-btn hidden-contact-phones_link item-clickable-phone fake-anchor" type="button">
#    <span class="hidden-contact-phones_text">
#     Llamar
#    </span>
#    <span class="animation_circle">
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#    </span>
#   </button>
#   <button aria-label="contact phone" class="icon-phone hidden-contact-phones_link see-phones-btn fake-anchor" type="button">
#    <span class="hidden-contact-phones_text">
#     Ver teléfono
#    </span>
#    <span class="animation_circle">
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#     <span class="circle">
#     </span>
#    </span>
#   </button>
#   <button class="trash-btn icon-trash-outline --old action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow" title="Descartar" type="button">
#    <span>
#     Descartar
#    </span>
#   </button>
#   <button class="icon-no-fav --old favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Favorito" title="Guardar" type="button">
#    <span>
#     Guardar
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================

# %% [markdown]
# ## Una vez comprobado, iteramos sobre todos los ficheros.txt de la carpeta Idealista, convertimos en Dataframe y exportamos finalmente a CSV

# %%
# Ruta de la carpeta IDEALISTA que contiene el HTML
carpeta = "../data/raw/idealista"

# Lista para almacenar todos los datos de viviendas
datos_todas_viviendas = []

# Iterar sobre todos los archivos .txt de la carpeta
for archivo in os.listdir(carpeta):
    if archivo.endswith(".txt"):
        # Leer el contenido del archivo
        print(archivo)
        ruta_archivo = os.path.join(carpeta, archivo)
        with open(ruta_archivo, 'r', encoding='utf-8') as file:
            html_content = file.read()
        
        # Crear el objeto BeautifulSoup
        soup = bs(html_content, "lxml")
        
        # Buscar el main content
        main_content = soup.select('main.listing-items.core-vitals-listing-map#main-content')
        if not main_content:
            print(f"No se encontró 'main-content' en el archivo: {archivo}")
            continue
        
        # Buscar todos los <div class="item-info-container"> dentro de main_content
        item_info_containers = main_content[0].select('div.item-info-container')
        
        for container in item_info_containers:
            # Agencia
            # agencia = container.select_one('picture.logo-branding a').get('title', '').strip() if container.select_one('picture.logo-branding a') else None
            
            # Título, calle y barrio
            enlace_vivienda = container.select_one('a.item-link')
            titulo = enlace_vivienda.get_text(strip=True) if enlace_vivienda else None
            title_attr = enlace_vivienda.get('title', '') if enlace_vivienda else ''

            # Extraer calle y barrio del título
            if ',' in title_attr:  # Si hay comas en el título
                partes = [parte.strip() for parte in title_attr.split(',')]  # Dividir por comas y eliminar espacios
                calle = partes[0] if len(partes) > 0 else None  # La primera parte es la calle
                municipio = partes[-1] if len(partes) > 0 else None # El último elemento es el municipio
                barrio = partes[-2] if len(partes) > 1 else None  # El penúltimo elemento es el barrio
            else:  # Si no hay comas
                palabras = title_attr.split()  # Dividir el título por espacios
                if len(palabras) > 2:  # Si hay más de dos palabras
                    calle = ' '.join(palabras[:-2])  # Todo excepto las dos últimas palabras como calle
                    barrio = ' '.join(palabras[-2:])  # Las dos últimas palabras como barrio
                    municipio = "Manises"
                else:  # Si hay dos palabras o menos
                    calle = None  # No hay suficiente información para la calle
                    barrio = ' '.join(palabras)  # Tomar todo como barrio
                    municipio = "Manises"
                    
            # Precio
            precio = container.select_one('div.price-row span.item-price').get_text(strip=True) if container.select_one('div.price-row span.item-price') else None
            precio = re.sub(r'[^\d]', '', precio) if precio else None  # Eliminar caracteres no numéricos
            
            # Habitaciones, metros cuadrados y planta
            detalles = container.select('div.item-detail-char span.item-detail')
            habitaciones = re.sub(r'[^\d]', '', detalles[0].get_text(strip=True)) if len(detalles) > 0 else None
            metros_cuadrados = re.sub(r'[^\d]', '', detalles[1].get_text(strip=True)) if len(detalles) > 1 else None
            planta = None
            for detalle in detalles:
                texto = detalle.get_text(strip=True)
                if "hab" in texto:
                    habitaciones = re.sub(r'[^\d]', '', texto)
                elif "m²" in texto:
                    metros_cuadrados = re.sub(r'[^\d]', '', texto)
                elif "Planta" in texto:
                    planta = texto

            # Tipo Vivienda
            if 'piso' in title_attr.lower():
                tipo_vivienda = 'Piso'
            elif 'casa' in title_attr.lower() and metros_cuadrados and float(metros_cuadrados) <= 100:
                tipo_vivienda = 'Casa'
            elif ('casa' in title_attr.lower() or 'chalet' in title_attr.lower()) and metros_cuadrados and float(metros_cuadrados) > 100:
                tipo_vivienda = 'Chalet'
            else:
                tipo_vivienda = None

            # Descripción
            descripcion_elemento = container.select_one('div.item-description p.ellipsis')
            descripcion = descripcion_elemento.get_text(strip=True) if descripcion_elemento else None
            
            # Número de baños (buscar "baños" en la descripción)
            numero_baños = None
            if descripcion:
                match = re.search(r'(\d+)\s*baños?', descripcion)
                numero_baños = match.group(1) if match else None

            elif descripcion and numero_baños is None:
                # Busca expresiones como "1 baño", "2 baños", "baño individual", etc.
                match = re.search(r'(\d+)\s*(?:baño|baños?|aseos?|wc)', descripcion, re.IGNORECASE)
                numero_baños = match.group(1) if match else None
            
            # Etiquetas
            etiquetas = [tag.get_text(strip=True) for tag in container.select('div.listing-tags-container span.listing-tags')]
            
            # Garaje incluido
            garaje = "Sí" if container.select_one('div.price-row span.item-parking') else "No"

            # Almacenar los datos en un diccionario
            datos_vivienda = {
                'calle': calle,
                'barrio': barrio,
                'municipio': municipio,
                'tipo_vivienda': tipo_vivienda,
                'titulo': titulo,
                'habitaciones': habitaciones,
                'metros_cuadrados': metros_cuadrados,
                'aseos': numero_baños,
                'planta': planta,
                'descripcion': descripcion,
                'etiquetas': etiquetas,
                'garaje': garaje,
                'precio': precio
            }
            datos_todas_viviendas.append(datos_vivienda)

# Crear un DataFrame consolidado
ideal = pd.DataFrame(datos_todas_viviendas)

# Convertir las columnas a tipo numérico
ideal['precio'] = ideal['precio'].astype(str).str.replace(r'[^\d]', '', regex=True)  # Eliminar caracteres no numéricos
ideal['precio'] = pd.to_numeric(ideal['precio'], errors='coerce') 
ideal['habitaciones'] = pd.to_numeric(ideal['habitaciones'], errors='coerce')
ideal['metros_cuadrados'] = pd.to_numeric(ideal['metros_cuadrados'], errors='coerce')
ideal['aseos'] = pd.to_numeric(ideal['aseos'], errors='coerce')

print(ideal.shape)
ideal.head(2)
# Out:
# idealista1.txt
# idealista10.txt
# idealista11.txt
# idealista12.txt
# idealista13.txt
# idealista14.txt
# idealista15.txt
# idealista16.txt
# idealista17.txt
# idealista18.txt
# idealista19.txt
# idealista2.txt
# idealista20.txt
# idealista21.txt
# idealista22.txt
# idealista3.txt
# idealista4.txt
# idealista5.txt
# idealista6.txt
# idealista7.txt
# idealista8.txt
# idealista9.txt
# (644, 13)
#                            calle      barrio municipio tipo_vivienda  \
# 0            Piso en calle Major  El Mercado   Manises          Piso
# 1  Ático en calle Penyal d'Ifach          10    Aldaia          None
#
#                                           titulo  habitaciones  \
# 0  Piso en calle Major, 183, El Mercado, Manises             3
# 1      Ático en calle Penyal d'Ifach, 10, Aldaia             3
#
#    metros_cuadrados  aseos                           planta  \
# 0                95    NaN  Planta 2ª exterior con ascensor
# 1               150    NaN  Planta 3ª exterior con ascensor
#
#                                          descripcion etiquetas garaje  precio
# 0  NEGOCIABLES\nVendo piso en muy buena zona, 81m...        []     No  160000
# 1                                               None        []     No  190000

# %% [markdown]
# #### Nos vamos a asegurar de que no **existen duplicados**, ya que hay muchos anuncios repetidos en la plataforma. Nos basaremos en específicas columnas importantes, ya que algunas son tipo lista y dan problemas a la hora de usar ***.drop_duplicates()***

# %%
print(f"Antes de eliminar duplicados: {ideal.shape}")
ideal = ideal.drop_duplicates(subset=['tipo_vivienda','habitaciones', 'metros_cuadrados', 'aseos', 'planta', 'garaje', 'precio'])
print(f"Después de eliminar duplicados: {ideal.shape}")
# Out:
# Antes de eliminar duplicados: (644, 13)
# Después de eliminar duplicados: (490, 13)

# %%
ideal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 490 entries, 0 to 642
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   calle             490 non-null    object
#  1   barrio            490 non-null    object
#  2   municipio         490 non-null    object
#  3   tipo_vivienda     427 non-null    object
#  4   titulo            490 non-null    object
#  5   habitaciones      490 non-null    int64
#  6   metros_cuadrados  490 non-null    int64
#  7   aseos             63 non-null     float64
#  8   planta            231 non-null    object
#  9   descripcion       484 non-null    object
#  10  etiquetas         490 non-null    object
#  11  garaje            490 non-null    object
#  12  precio            490 non-null    int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 53.6+ KB

# %%
# ideal["aseos"].value_counts()

# %%
# ideal["habitaciones"].value_counts()

# %%
# ideal.loc[ideal["precio"] == 700000, :]

# %%
ideal.to_csv("../data/procesado/viviendasIdealista.csv", index=True)

# %% [markdown]
# ## Siguiente, Scrapping con el HTML de Pisos (Manises y alrededores)

# %% [markdown]
# Primera Pagina: https://www.pisos.com/venta/pisos-manises/

# %% [markdown]
# ### Comprobamos que BeautifulSoup funciona con uno de los ficheros de Pisos

# %%
# Leer el archivo HTML
with open('../data/raw/pisos/pisos1.txt', 'r', encoding='utf-8') as file:
    html_content = file.read()

# Analizar el contenido HTML de una forma estructurada y fácil de manipular.
soup = bs(html_content, "lxml") # Parser LXML

# Usar select para buscar el elemento <main>
main_content = soup.select('div.grid__wrapper')

# Buscar todos los <div class="item-info-container"> dentro de main_content
item_info_containers = main_content[0].select('div.ad-preview__bottom')

# Mostrar la información de cada elemento encontrado
for i, container in enumerate(item_info_containers, start=1):
    print(f"Elemento {i}:\n")
    print(container.prettify())
    print("\n" + "="*50 + "\n")
# Out:
# Elemento 1:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      280.000 €
#     </span>
#     <span class="ad-preview__type">
#      Obra nueva
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/atico-la_canyada_la_canada46182-4997616700_109700/">
#     Ático en Carrer 30, 32
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     La Canyada - La Cañada (Paterna)
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      2 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      1 baño
#     </p>
#     <p class="ad-preview__char p-sm">
#      99 m²
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Tipo 16. Ático en un inmueble de obra nueva de 99 m2 de superficie construida y situado en la zona de Paterna. Está estructurado en 2 habitaciones, 1 baño completo y terraza de 14.80 m2. Aporta como extras ascensor.
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo" data-ad-id="4997616700.109700" data-ad-price="280000" data-contactpos="ZoneSpecialist" data-is-newdevelopment="false" data-is-tipology="true">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla,obranueva-profesional,P46/M46190/G4619004,5,False,4997616700.109700,280000" data-is-incotel="true" data-number="960365113">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#   <button class="contact-box__whats" data-lnk-pagename="_ctaparrwhatsapp">
#    <span>
#     WhatsApp
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 2:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      376.500 €
#     </span>
#     <span class="ad-preview__type">
#      Obra nueva
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/atico-santa_rita_alborgi46980-4565007725_109700/">
#     Ático en calle de los Molinos,  s/n
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     Santa Rita-Alborgí (Paterna)
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      3 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      2 baños
#     </p>
#     <p class="ad-preview__char p-sm">
#      218 m²
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Tipo D. 10º-39. Ático en un inmueble de obra nueva de 218 m2 de superficie construida y situado en la zona de Paterna, acomodado en planta 10. Está estructurado en 3 habitaciones, 2 baños completos y terraza de 113,13 m2. Aporta como extras garaje y trastero.
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo" data-ad-id="4565007725.109700" data-ad-price="376500" data-contactpos="ZoneSpecialist" data-is-newdevelopment="false" data-is-tipology="true">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla,obranueva-profesional,P46/M46190/G4619005,5,False,4565007725.109700,376500" data-is-incotel="true" data-number="960365113">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#   <button class="contact-box__whats" data-lnk-pagename="_ctaparrwhatsapp">
#    <span>
#     WhatsApp
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 3:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      244.000 €
#     </span>
#     <span class="ad-preview__type">
#      Obra nueva
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/piso-paterna_centre46980-4811981437_109700/">
#     Piso en Carrer Miguel Hernández, 10
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     Centre (Paterna)
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      3 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      2 baños
#     </p>
#     <p class="ad-preview__char p-sm">
#      86 m²
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Vivienda 12. Piso en una finca de obra nueva de 86 m2 de superficie construida y emplazado en la zona de Paterna. Está dispuesto en 3 habitaciones, 2 baños completos y terraza de 7.87 m2. Cuenta como extras ascensor.
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo" data-ad-id="4811981437.109700" data-ad-price="244000" data-contactpos="ZoneSpecialist" data-is-newdevelopment="false" data-is-tipology="true">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla,obranueva-profesional,P46/M46190/G4619002,5,False,4811981437.109700,244000" data-is-incotel="true" data-number="960365113">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#   <button class="contact-box__whats" data-lnk-pagename="_ctaparrwhatsapp">
#    <span>
#     WhatsApp
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 4:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      208.000 €
#     </span>
#     <span class="ad-preview__type">
#      Obra nueva
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/piso-quart_de_poblet_centro_urbano-5016628969_109700/">
#     Piso en calle Federica Montseny,  S/N
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     Quart de Poblet
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      2 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      1 baño
#     </p>
#     <p class="ad-preview__char p-sm">
#      77 m²
#     </p>
#     <p class="ad-preview__char p-sm">
#      Bajo
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     V001-esc. 1 - pb - a. Piso en un inmueble de obra nueva de 77 m² de superficie construida y situado en la zona de quart de poblet,...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo contact-box--left" data-ad-id="5016628969.109700" data-ad-price="208000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="true" data-new-development-parent-id="4934257879.109700">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-tipon,obranueva-profesional,P46/M46102/L57646,5,False,5016628969.109700,208000" data-is-incotel="true" data-number="919377716">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 5:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      273.000 €
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/chalet-alameda_parc-44245697668_100500/">
#     Chalet en Alameda Park
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     Alameda Parc (Manises)
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      5 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      3 baños
#     </p>
#     <p class="ad-preview__char p-sm">
#      280 m²
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Casa o chalet en venta en calle concheta, alameda park
#
# J.a.f. Inmobiliaria dispone en exclusiva de éste chalet en la urbanización...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo" data-ad-id="44245697668.100500" data-ad-price="273000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="false">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-sm,venta-profesional-viviendas,P46/M46159/G4615901,3,False,44245697668.100500,273000" data-is-incotel="true" data-number="960364726">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#   <button class="contact-box__whats" data-lnk-pagename="_ctaparrwhatsapp">
#    <span>
#     WhatsApp
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 6:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      178.000 €
#     </span>
#     <span class="ad-preview__type">
#      Obra nueva
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/piso-quart_de_poblet_centro_urbano-4925666724_109700/">
#     Piso en calle Federica Montseny,  S/N
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     Quart de Poblet
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      1 hab.
#     </p>
#     <p class="ad-preview__char p-sm">
#      1 baño
#     </p>
#     <p class="ad-preview__char p-sm">
#      65 m²
#     </p>
#     <p class="ad-preview__char p-sm">
#      5ª planta
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     V041-esc. 1 - p05 - f. Piso en un inmueble de obra nueva de 765  m² de superficie construida y situado en la zona de quart de pobl...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo contact-box--left" data-ad-id="4925666724.109700" data-ad-price="178000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="true" data-new-development-parent-id="4934257879.109700">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-tipon,obranueva-profesional,P46/M46102/L57646,5,False,4925666724.109700,178000" data-is-incotel="true" data-number="919377716">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 7:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      239.900 €
#     </span>
#     <span class="ad-preview__type">
#      Obra nueva
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/piso-paterna_centre46980-4786061176_109700/">
#     Piso en Carrer Miguel Hernández, 10
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     Centre (Paterna)
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      3 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      2 baños
#     </p>
#     <p class="ad-preview__char p-sm">
#      86 m²
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Vivienda 9. Piso en una finca de obra nueva de 86 m² de superficie construida y emplazado en la zona de paterna. Está dispuesto en...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo" data-ad-id="4786061176.109700" data-ad-price="239900" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="true" data-new-development-parent-id="4727655628.109700">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-tipon,obranueva-profesional,P46/M46190/G4619002,5,False,4786061176.109700,239900" data-is-incotel="true" data-number="960365113">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#   <button class="contact-box__whats" data-lnk-pagename="_ctaparrwhatsapp">
#    <span>
#     WhatsApp
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 8:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      246.000 €
#     </span>
#     <span class="ad-preview__type">
#      Obra nueva
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/piso-manises_centre-4951851843_109700/">
#     Piso en Carrer de les Roses, 20
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     Centre (Manises)
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      3 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      2 baños
#     </p>
#     <p class="ad-preview__char p-sm">
#      114 m²
#     </p>
#     <p class="ad-preview__char p-sm">
#      2ª planta
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Escalera 5-2ºb. Piso en una finca de obra nueva de 114 m² de superficie construida y emplazado en la zona de manises, posicionado ...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo" data-ad-id="4951851843.109700" data-ad-price="246000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="true" data-new-development-parent-id="3129343086.109700">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-tipon,obranueva-profesional,P46/M46159/G4615902,5,False,4951851843.109700,246000" data-is-incotel="true" data-number="919374849">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#   <button class="contact-box__whats" data-lnk-pagename="_ctaparrwhatsapp">
#    <span>
#     WhatsApp
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 9:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      295.000 €
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/chalet_unifamiliar-la_canyada_la_canada46182-48421931825_995884/">
#     Chalet unifamiliar en La Canyada - La Cañada
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     La Canyada - La Cañada (Paterna)
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      3 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      1 baño
#     </p>
#     <p class="ad-preview__char p-sm">
#      85 m²
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Chalet en venta en la localidad de la cañada, cercana a la población, al transporte público y a la zona comercial, con buenos acce...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo" data-ad-id="48421931825.995884" data-ad-price="295000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="false">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-sm,venta-profesional-viviendas,P46/M46190/G4619004,3,False,48421931825.995884,295000" data-is-incotel="true" data-number="960364641">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#   <button class="contact-box__whats" data-lnk-pagename="_ctaparrwhatsapp">
#    <span>
#     WhatsApp
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 10:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      510.000 €
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/piso-la_canyada_la_canada46182-48424314583_106700/">
#     Piso en La Canyada - La Cañada
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     La Canyada - La Cañada (Paterna)
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      5 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      3 baños
#     </p>
#     <p class="ad-preview__char p-sm">
#      240 m²
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Venta de edificio, en su totalidad, en la cañada.
# Excelente situación en el centro del pueblo, próximo al metro, comercios, hospit...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo" data-ad-id="48424314583.106700" data-ad-price="510000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="false">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-sm,venta-profesional-viviendas,P46/M46190/G4619004,3,False,48424314583.106700,510000" data-is-incotel="true" data-number="960364211">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#   <button class="contact-box__whats" data-lnk-pagename="_ctaparrwhatsapp">
#    <span>
#     WhatsApp
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 11:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      299.000 €
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/casa-santa_rita_alborgi46980-49180420137_108900/">
#     Casa en Santa Rita-Alborgí
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     Santa Rita-Alborgí (Paterna)
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      3 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      3 baños
#     </p>
#     <p class="ad-preview__char p-sm">
#      205 m²
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Primer grupo vivendia pone a la venta adosado en paterna - zona los molinoseste impresionante adosado de 200 m² se encuentra en la...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo" data-ad-id="49180420137.108900" data-ad-price="299000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="false">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-sm,venta-profesional-viviendas,P46/M46190/G4619005,3,False,49180420137.108900,299000" data-is-incotel="true" data-number="960365076">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#   <button class="contact-box__whats" data-lnk-pagename="_ctaparrwhatsapp">
#    <span>
#     WhatsApp
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 12:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      246.000 €
#     </span>
#     <span class="ad-preview__type">
#      Obra nueva
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/piso-manises_centre-47525751629_993432/">
#     Piso en Carrer de les Roses, 20
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     Centre (Manises)
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      3 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      2 baños
#     </p>
#     <p class="ad-preview__char p-sm">
#      107 m²
#     </p>
#     <p class="ad-preview__char p-sm">
#      3ª planta
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Obras ya iniciadas
# En rosas20 te ofrecemos una estupenda oportunidad de mejorar tu calidad de vida disfrutando de un entorno armon...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo" data-ad-id="47525751629.993432" data-ad-price="246000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="true" data-new-development-parent-id="47580718808.993432">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-tipon,obranueva-profesional,P46/M46159/G4615902,5,False,47525751629.993432,246000" data-is-incotel="true" data-number="919377617">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#   <button class="contact-box__whats" data-lnk-pagename="_ctaparrwhatsapp">
#    <span>
#     WhatsApp
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 13:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      110.000 €
#     </span>
#    </div>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/piso-manises_el_mercat-47536956236_100200/">
#     Piso en El Mercat
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     El Mercat (Manises)
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      2 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      1 baño
#     </p>
#     <p class="ad-preview__char p-sm">
#      60 m²
#     </p>
#     <p class="ad-preview__char p-sm">
#      1ª planta
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Referencia: mis – 26.
#
# Tecnocasa vende en exclusiva.
#
# Piso en finca del año 1960, orientación oeste. Exterior con balcon.
#
# La vivi...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo contact-box--left" data-ad-id="47536956236.100200" data-ad-price="110000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="false">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-sm,venta-profesional-viviendas,P46/M46159/G4615904,3,False,47536956236.100200,110000" data-is-incotel="true" data-number="960365018">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 14:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      475.000 €
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/piso-santa_rita_alborgi46980-48411143776_108900/">
#     Piso en Santa Rita-Alborgí
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     Santa Rita-Alborgí (Paterna)
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      3 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      2 baños
#     </p>
#     <p class="ad-preview__char p-sm">
#      118 m²
#     </p>
#     <p class="ad-preview__char p-sm">
#      8ª planta
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Primer grupo vivendia pone a la venta este magnífico ático en una de las zonas más exclusivas y en expansión de paterna. Con todos...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo" data-ad-id="48411143776.108900" data-ad-price="475000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="false">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-sm,venta-profesional-viviendas,P46/M46190/G4619005,3,False,48411143776.108900,475000" data-is-incotel="true" data-number="960365076">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#   <button class="contact-box__whats" data-lnk-pagename="_ctaparrwhatsapp">
#    <span>
#     WhatsApp
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 15:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      225.000 €
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/piso-manises_el_carme-45066211886_526393/">
#     Piso en Carrer de Paterna
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     El Carme (Manises)
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      3 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      2 baños
#     </p>
#     <p class="ad-preview__char p-sm">
#      117 m²
#     </p>
#     <p class="ad-preview__char p-sm">
#      3ª planta
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     " " " " "grupo inmobiliario selling house te propone una gran oportunidad " " " " "
#
# Ubicado en manises a 1 minuto del hospital y...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo" data-ad-id="45066211886.526393" data-ad-price="225000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="false">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-sm,venta-profesional-viviendas,P46/M46159/G4615903,3,False,45066211886.526393,225000" data-is-incotel="false" data-number="689608952">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#   <button class="contact-box__whats" data-lnk-pagename="_ctaparrwhatsapp">
#    <span>
#     WhatsApp
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 16:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      1.250.000 €
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/chalet-la_canyada_la_canada46182-50021382514_100500/">
#     Chalet en La Cañada
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     La Canyada - La Cañada (Paterna)
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      4 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      4 baños
#     </p>
#     <p class="ad-preview__char p-sm">
#      439 m²
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Excelente  chalet de lujo en venta en el plantío, la cañada,  a tan solo 10 min del aeropuerto y a  15 min de valencia centro.  Ub...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo" data-ad-id="50021382514.100500" data-ad-price="1250000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="false">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-sm,venta-profesional-viviendas,P46/M46190/G4619004,3,False,50021382514.100500,1250000" data-is-incotel="true" data-number="960365913">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#   <button class="contact-box__whats" data-lnk-pagename="_ctaparrwhatsapp">
#    <span>
#     WhatsApp
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 17:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      223.000 €
#     </span>
#     <span class="ad-preview__type">
#      Obra nueva
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/piso-santa_rita_alborgi46980-5014065115_109700/">
#     Piso en calle Dels Pins &amp; Carrer de Les Roses,  S/N
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     Santa Rita-Alborgí (Paterna)
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      3 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      2 baños
#     </p>
#     <p class="ad-preview__char p-sm">
#      107 m²
#     </p>
#     <p class="ad-preview__char p-sm">
#      4ª planta
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Escalera a, 4º c. Piso en una finca de obra nueva de 107 m² de superficie construida y emplazado en la zona de paterna, posicionad...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo contact-box--left" data-ad-id="5014065115.109700" data-ad-price="223000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="true" data-new-development-parent-id="4384215347.109700">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-tipon,obranueva-profesional,P46/M46190/G4619005,5,False,5014065115.109700,223000" data-is-incotel="true" data-number="919377626">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 18:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      360.000 €
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/casa_adosada-aldaia_centro_urbano-43406478513_100500/">
#     Casa adosada en Avinguda de Miguel Hernández
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     Aldaia
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      3 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      1 baño
#     </p>
#     <p class="ad-preview__char p-sm">
#      201 m²
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Esta impresionante propiedad ofrece una combinación única de confort, privacidad y seguridad. Ventanas de pvc con climalit, oscilo...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo" data-ad-id="43406478513.100500" data-ad-price="360000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="false">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-sm,venta-profesional-viviendas,P46/M46021/L57231,3,False,43406478513.100500,360000" data-is-incotel="true" data-number="960364964">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#   <button class="contact-box__whats" data-lnk-pagename="_ctaparrwhatsapp">
#    <span>
#     WhatsApp
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 19:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      250.000 €
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/casa-quart_de_poblet_centro_urbano-47544967871_100500/">
#     Casa en Centro del Pueblo
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     Quart de Poblet
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      3 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      1 baño
#     </p>
#     <p class="ad-preview__char p-sm">
#      265 m²
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Disponemos en exclusiva  de una casa independiente  en dos alturas ,  la panta baja tiene 153 metros  es diáfana con muchísimas po...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo contact-box--left" data-ad-id="47544967871.100500" data-ad-price="250000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="false">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-sm,venta-profesional-viviendas,P46/M46102/L57646,3,False,47544967871.100500,250000" data-is-incotel="true" data-number="960364877">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 20:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      299.000 €
#     </span>
#     <span class="ad-preview__type">
#      Obra nueva
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/piso-manises_el_mercat-4585623642_109700/">
#     Piso en calle Francesc Ferrer Pastor,  s/n
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     El Mercat (Manises)
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      4 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      2 baños
#     </p>
#     <p class="ad-preview__char p-sm">
#      147 m²
#     </p>
#     <p class="ad-preview__char p-sm">
#      2ª planta
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Planta 2, escalera 1, puerta c.  Piso en un edificio de obra nueva de 147 m² de superficie construida y ubicado en la zona de soto...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo contact-box--left" data-ad-id="4585623642.109700" data-ad-price="299000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="true" data-new-development-parent-id="4504400860.109700">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-tipon,obranueva-profesional,P46/M46159/G4615904,5,False,4585623642.109700,299000" data-is-incotel="true" data-number="960365161">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 21:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      146.000 €
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/piso-manises_centre-47591344813_100900/">
#     Piso en Centro
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     Centre (Manises)
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      4 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      1 baño
#     </p>
#     <p class="ad-preview__char p-sm">
#      120 m²
#     </p>
#     <p class="ad-preview__char p-sm">
#      1ª planta
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Oportunidad de piso exterior con mucha luz. Dispone de 4 amplios dormitorios, un amplio salón lleno de luz y 1 baño.
# La cocina est...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo" data-ad-id="47591344813.100900" data-ad-price="146000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="false">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-sm,venta-profesional-viviendas,P46/M46159/G4615902,3,False,47591344813.100900,146000" data-is-incotel="true" data-number="960364466">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#   <button class="contact-box__whats" data-lnk-pagename="_ctaparrwhatsapp">
#    <span>
#     WhatsApp
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 22:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      208.000 €
#     </span>
#     <span class="ad-preview__type">
#      Obra nueva
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/piso-quart_de_poblet_centro_urbano-5016628969_109700/">
#     Piso en calle Federica Montseny,  S/N
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     Quart de Poblet
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      2 habs.
#     </p>
# ...
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-sm,venta-profesional-viviendas,P46/M46159/G4615904,3,False,49168342474.100500,114000" data-is-incotel="true" data-number="865735289">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 28:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      240.000 €
#     </span>
#     <span class="ad-preview__drop">
#      20.000 € (-8%)
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/casa-alameda_parc-40095374388_109300/">
#     Casa en Alameda Parc
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     Alameda Parc (Manises)
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      3 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      1 baño
#     </p>
#     <p class="ad-preview__char p-sm">
#      236 m²
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Te gustaría vivir en plena naturaleza a solo 15 minutos de valencia, se vende estupenda casa con terreno en la urbanización la pre...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo" data-ad-id="40095374388.109300" data-ad-price="240000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="false">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-sm,venta-profesional-viviendas,P46/M46159/G4615901,3,False,40095374388.109300,240000" data-is-incotel="true" data-number="960365453">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#   <button class="contact-box__whats" data-lnk-pagename="_ctaparrwhatsapp">
#    <span>
#     WhatsApp
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 29:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      220.000 €
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/chalet-zona_aeroport-47564340841_100500/">
#     Chalet en Urb. Lamallá
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     Zona Aeroport (Manises)
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      3 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      1 baño
#     </p>
#     <p class="ad-preview__char p-sm">
#      170 m²
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     ¡Oportunidad única!
#
# Chalet independiente en collado - la malla por solo 220.000€.
#
# Esta magnífica vivienda, construida en 1983,...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo" data-ad-id="47564340841.100500" data-ad-price="220000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="false">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-sm,venta-profesional-viviendas,P46/M46159/G4615906,3,False,47564340841.100500,220000" data-is-incotel="true" data-number="960364757">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#   <button class="contact-box__whats" data-lnk-pagename="_ctaparrwhatsapp">
#    <span>
#     WhatsApp
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 30:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      135.000 €
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/piso-aldaia_centro_urbano-50075173668_101800/">
#     Piso en Aldaia
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     Aldaia
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      1 hab.
#     </p>
#     <p class="ad-preview__char p-sm">
#      1 baño
#     </p>
#     <p class="ad-preview__char p-sm">
#      70 m²
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Increible vivienda reformada con amplia terraza en la localidad de aldaya.
# Piso en primera altura sin ascensor, 70 mts, 1 habitaci...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo" data-ad-id="50075173668.101800" data-ad-price="135000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="false">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-sm,venta-profesional-viviendas,P46/M46021/L57231,3,False,50075173668.101800,135000" data-is-incotel="true" data-number="960365078">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#   <button class="contact-box__whats" data-lnk-pagename="_ctaparrwhatsapp">
#    <span>
#     WhatsApp
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 31:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      255.000 €
#     </span>
#     <span class="ad-preview__type">
#      Obra nueva
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/piso-manises_el_mercat-4772312990_109700/">
#     Piso en calle Francesc Ferrer Pastor,  s/n
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     El Mercat (Manises)
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      3 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      2 baños
#     </p>
#     <p class="ad-preview__char p-sm">
#      100 m²
#     </p>
#     <p class="ad-preview__char p-sm">
#      1ª planta
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Planta 1, escalera 1, puerta a.  Piso en un edificio de obra nueva de 100 m² de superficie construida y ubicado en la zona de soto...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo contact-box--left" data-ad-id="4772312990.109700" data-ad-price="255000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="true" data-new-development-parent-id="4504400860.109700">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-tipon,obranueva-profesional,P46/M46159/G4615904,5,False,4772312990.109700,255000" data-is-incotel="true" data-number="960365161">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 32:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      215.000 €
#     </span>
#     <span class="ad-preview__type">
#      Obra nueva
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/piso-manises_el_mercat-4610243605_109700/">
#     Piso en calle Francesc Ferrer Pastor,  s/n
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     El Mercat (Manises)
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      2 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      2 baños
#     </p>
#     <p class="ad-preview__char p-sm">
#      79 m²
#     </p>
#     <p class="ad-preview__char p-sm">
#      4ª planta
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Planta 4, escalera 3, puerta c.  Piso en un edificio de obra nueva de 79 m² de superficie construida y ubicado en la zona de soto ...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo contact-box--left" data-ad-id="4610243605.109700" data-ad-price="215000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="true" data-new-development-parent-id="4504400860.109700">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-tipon,obranueva-profesional,P46/M46159/G4615904,5,False,4610243605.109700,215000" data-is-incotel="true" data-number="960365161">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 33:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      243.000 €
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/piso-manises_el_mercat-43432351558_100500/">
#     Piso en El Mercado
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     El Mercat (Manises)
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      4 habs.
#     </p>
#     <p class="ad-preview__char p-sm">
#      2 baños
#     </p>
#     <p class="ad-preview__char p-sm">
#      131 m²
#     </p>
#     <p class="ad-preview__char p-sm">
#      1ª planta
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Este magnífico piso en la mejor zona de manises ofrece un ambiente acogedor y luminoso que puede mejorar tus emociones diarias y t...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo contact-box--left" data-ad-id="43432351558.100500" data-ad-price="243000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="false">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-sm,venta-profesional-viviendas,P46/M46159/G4615904,3,False,43432351558.100500,243000" data-is-incotel="true" data-number="960364885">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#  </div>
# </div>
#
#
# ==================================================
#
# Elemento 34:
#
# <div class="ad-preview__bottom">
#  <div class="ad-preview__info">
#   <div class="ad-preview__section ad-preview__section--has-textlink">
#    <div class="ad-preview__inline">
#     <span class="ad-preview__price">
#      49.000 €
#     </span>
#     <span class="ad-preview__drop">
#      2.000 € (-4%)
#     </span>
#    </div>
#    <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="39">
#     <a class="txtlnk_39" data-url="http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&amp;iu=/4900/vocento.pisos" href="#" rel="nofollow">
#      Calcula tu hipoteca
#     </a>
#    </span>
#   </div>
#   <div class="ad-preview__section">
#    <a class="ad-preview__title" href="/comprar/loft-aldaia_centro_urbano-45070499629_100900/">
#     Loft en calle de Coladores
#    </a>
#    <p class="p-sm ad-preview__subtitle">
#     Aldaia
#    </p>
#   </div>
#   <div class="ad-preview__section">
#    <div class="ad-preview__inline">
#     <p class="ad-preview__char p-sm">
#      1 hab.
#     </p>
#     <p class="ad-preview__char p-sm">
#      1 baño
#     </p>
#     <p class="ad-preview__char p-sm">
#      46 m²
#     </p>
#    </div>
#   </div>
#   <div class="ad-preview__section u-hide u-show--s768">
#    <p class="ad-preview__description">
#     Habitale presenta este loft/oficina en aldaia, zona centro de aldaia, próximo al ayuntamiento de aldaia.
# Importante: en el catast...
#    </p>
#   </div>
#  </div>
#  <div class="contact-box js-contactInfo" data-ad-id="45070499629.100900" data-ad-price="49000" data-contactpos="AdPreview" data-is-newdevelopment="false" data-is-tipology="false">
#   <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-sm,venta-profesional-viviendas,P46/M46021/L57231,3,False,45070499629.100900,49000" data-is-incotel="true" data-number="960364613">
#    Llamar
#   </button>
#   <button class="contact-box__email">
#    Contactar
#   </button>
#   <button class="contact-box__drop-alert u-show--s768">
#    Avísame si baja
#   </button>
#   <button class="contact-box__whats" data-lnk-pagename="_ctaparrwhatsapp">
#    <span>
#     WhatsApp
#    </span>
#   </button>
#  </div>
# </div>
#
#
# ==================================================

# %% [markdown]
# ## Una vez comprobado, iteramos sobre todos los ficheros.txt de la carpeta Pisos, convertimos en Dataframe y exportamos finalmente a CSV

# %%
# Ruta de la carpeta PISOS que contiene el HTML
carpeta = "../data/raw/pisos"

# Lista para almacenar todos los datos de viviendas
datos_todas_viviendas = []

# Iterar sobre todos los archivos .txt de la carpeta
for archivo in os.listdir(carpeta):
    if archivo.endswith(".txt"):
        # Leer el contenido del archivo
        print(archivo)
        ruta_archivo = os.path.join(carpeta, archivo)
        with open(ruta_archivo, 'r', encoding='utf-8') as file:
            html_content = file.read()
        
        # Crear el objeto BeautifulSoup
        soup = bs(html_content, "lxml")
        
        # Buscar el contenedor principal
        main_content = soup.select('div.grid__wrapper')
        if not main_content:
            print(f"No se encontró el contenido principal en el archivo: {archivo}")
            continue
        
        # Buscar todos los <div class="ad-preview__bottom"> dentro de main_content
        item_info_containers = main_content[0].select('div.ad-preview__bottom')
        
        for container in item_info_containers:
            # Agencia (si existe información de contacto, podría deducirse como agencia)
            # agencia = container.select_one('div.contact-box')
            # agencia = agencia.get('data-is-newdevelopment', '').strip() if agencia else None
            
            # Precio
            precio = container.select_one('span.ad-preview__price').get_text(strip=True) if container.select_one('span.ad-preview__price') else None
            precio = re.sub(r'[^\d]', '', precio) if precio else None  # Eliminar caracteres no numéricos
            
            # Título, calle y barrio
            enlace_vivienda = container.select_one('a.ad-preview__title')
            titulo = enlace_vivienda.get_text(strip=True) if enlace_vivienda else None
            calle = titulo.split(',')[0].strip() if titulo else None
            
            subtitulo = container.select_one('p.ad-preview__subtitle')
            barrio = subtitulo.get_text(strip=True) if subtitulo else None
            
            # Municipio (deducido del subtítulo si está estructurado como "barrio (municipio)")
            municipio = None
            if subtitulo and '(' in subtitulo.get_text():
                municipio = re.search(r'\((.*?)\)', subtitulo.get_text()).group(1).strip()
            
            # Habitaciones, baños, metros cuadrados y planta
            detalles = container.select('p.ad-preview__char')
            habitaciones = None
            numero_baños = None
            metros_cuadrados = None
            planta = None
            for detalle in detalles:
                texto = detalle.get_text(strip=True)
                if "habs" in texto:
                    habitaciones = re.sub(r'[^\d]', '', texto)
                elif "baños" in texto:
                    numero_baños = re.sub(r'[^\d]', '', texto)
                elif "m²" in texto:
                    metros_cuadrados = re.sub(r'[^\d]', '', texto)
                elif "planta" in texto.lower():
                    planta = texto
            
            # Tipo de vivienda basado en el título y metros cuadrados
            tipo_vivienda = container.select_one('a.ad-preview__title').get_text(strip=True) if container.select_one('a.ad-preview__title') else None
            if tipo_vivienda:
                if 'piso' in tipo_vivienda.lower() or 'apartamento' in tipo_vivienda.lower():
                    tipo_vivienda = 'Piso'
                elif 'atico' in tipo_vivienda.lower() or 'ático' in tipo_vivienda.lower():
                    tipo_vivienda = 'Piso'
                elif 'duplex' in tipo_vivienda.lower() or 'dúplex' in tipo_vivienda.lower():
                    tipo_vivienda = 'Piso'
                elif 'casa' in tipo_vivienda.lower():
                    tipo_vivienda = 'Casa'
                elif 'chalet' in tipo_vivienda.lower():
                    tipo_vivienda = 'Chalet'
                else:
                    tipo_vivienda = None

            # Descripción
            descripcion_elemento = container.select_one('p.ad-preview__description')
            descripcion = descripcion_elemento.get_text(strip=True) if descripcion_elemento else None
            
            # Etiquetas (no presente explícitamente, pero se puede construir con tipo de vivienda u otros datos)
            etiquetas = [tipo_vivienda] if tipo_vivienda else []
            
            # Garaje (inferencia si está mencionado en la descripción)
            garaje = "Sí" if descripcion and "garaje" in descripcion.lower() else "No"
            
            # Almacenar los datos en un diccionario
            datos_vivienda = {
                'calle': calle,
                'barrio': barrio,
                'municipio': municipio,
                'tipo_vivienda': tipo_vivienda,
                'titulo': titulo,
                'habitaciones': habitaciones,
                'metros_cuadrados': metros_cuadrados,
                'aseos': numero_baños,
                'planta': planta,
                'descripcion': descripcion,
                'etiquetas': etiquetas,
                'garaje': garaje,
                'precio': precio
            }
            datos_todas_viviendas.append(datos_vivienda)

# Crear un DataFrame consolidado
pisos = pd.DataFrame(datos_todas_viviendas)

# Convertir las columnas a tipo numérico
pisos['precio'] = pd.to_numeric(pisos['precio'], errors='coerce')
pisos['habitaciones'] = pd.to_numeric(pisos['habitaciones'], errors='coerce')
pisos['aseos'] = pd.to_numeric(pisos['aseos'], errors='coerce')
pisos['metros_cuadrados'] = pd.to_numeric(pisos['metros_cuadrados'], errors='coerce')

# Mostrar los primeros resultados
print(pisos.shape)
pisos.head(3)
# Out:
# pisos1.txt
# pisos10.txt
# pisos11.txt
# pisos12.txt
# pisos2.txt
# pisos3.txt
# pisos4.txt
# pisos5.txt
# pisos6.txt
# pisos7.txt
# pisos8.txt
# pisos9.txt
# (370, 13)
#                              calle                            barrio  \
# 0               Ático en Carrer 30  La Canyada - La Cañada (Paterna)
# 1    Ático en calle de los Molinos      Santa Rita-Alborgí (Paterna)
# 2  Piso en Carrer Miguel Hernández                  Centre (Paterna)
#
#   municipio tipo_vivienda                               titulo  habitaciones  \
# 0   Paterna          Piso               Ático en Carrer 30, 32           2.0
# 1   Paterna          Piso  Ático en calle de los Molinos,  s/n           3.0
# 2   Paterna          Piso  Piso en Carrer Miguel Hernández, 10           3.0
#
#    metros_cuadrados  aseos planta  \
# 0                99    NaN   None
# 1               218    2.0   None
# 2                86    2.0   None
#
#                                          descripcion etiquetas garaje  \
# 0  Tipo 16. Ático en un inmueble de obra nueva de...    [Piso]     No
# 1  Tipo D. 10º-39. Ático en un inmueble de obra n...    [Piso]     Sí
# 2  Vivienda 12. Piso en una finca de obra nueva d...    [Piso]     No
#
#      precio
# 0  280000.0
# 1  376500.0
# 2  244000.0

# %% [markdown]
# #### Nos vamos a asegurar de que no **existen duplicados**, ya que hay muchos anuncios repetidos en la plataforma. Nos basaremos en específicas columnas importantes, ya que algunas son tipo lista y dan problemas a la hora de usar ***.drop_duplicates()***

# %%
print(f"Antes de eliminar duplicados: {pisos.shape}")
pisos = pisos.drop_duplicates(subset=['tipo_vivienda','habitaciones', 'metros_cuadrados', 'aseos', 'planta', 'garaje', 'precio'])
print(f"Después de eliminar duplicados: {pisos.shape}")
# Out:
# Antes de eliminar duplicados: (370, 13)
# Después de eliminar duplicados: (336, 13)

# %%
pisos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 336 entries, 0 to 369
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   calle             336 non-null    object
#  1   barrio            336 non-null    object
#  2   municipio         252 non-null    object
#  3   tipo_vivienda     335 non-null    object
#  4   titulo            336 non-null    object
#  5   habitaciones      303 non-null    float64
#  6   metros_cuadrados  336 non-null    int64
#  7   aseos             229 non-null    float64
#  8   planta            134 non-null    object
#  9   descripcion       334 non-null    object
#  10  etiquetas         336 non-null    object
#  11  garaje            336 non-null    object
#  12  precio            333 non-null    float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 36.8+ KB

# %%
# pisos["aseos"].value_counts()

# %%
# pisos["habitaciones"].value_counts()

# %%
# pisos["tipo_vivienda"].value_counts()

# %%
pisos.to_csv("../data/procesado/viviendasPisos.csv", index=True)

# %% [markdown]
# ## Siguiente, Scrapping con el HTML de Fotocasa

# %% [markdown]
# Primera pagina: https://www.fotocasa.es/es/comprar/viviendas/manises/todas-las-zonas/l

# %% [markdown]
# ### Comprobamos que BeautifulSoup funciona con uno de los ficheros de Fotocasa

# %%
# Leer el archivo HTML
with open('../data/raw/foto/fotocasa1.txt', 'r', encoding='utf-8') as file:
    html_content = file.read()

# Analizar el contenido HTML de una forma estructurada y fácil de manipular.
soup = bs(html_content, "lxml") # Parser LXML
soup

# %% [markdown]
# ### Fotocasa no nos lo pone facil para scrappear por sus etiquetas, asi que vamos a hacerlo por partes, una para ciertas etiquetas y almacenarlas en un dataframe, y otra parte para otras etiquetarlas y guardarlas en otro dataframe y finalmente unificarlos para exportar a CSV

# %% [markdown]
# #### Etiquetas: **'re-CardPackPremium', 're-CardPackAdvance', 're-CardPackBasic'**

# %%
# Ruta de la carpeta FOTOCASA que contiene el HTML
carpeta = "../data/raw/fotocasa"

# Lista para almacenar todos los datos de viviendas
datos_todas_viviendas = []

# Iterar sobre todos los archivos .txt en la carpeta
for archivo in os.listdir(carpeta):
    if archivo.endswith(".txt"):
        # Leer el contenido del archivo
        print("\n>>>>>>>>>>>>>>",archivo, "<<<<<<<<<<<<<<")
        ruta_archivo = os.path.join(carpeta, archivo)
        with open(ruta_archivo, 'r', encoding='utf-8') as file:
            html_content = file.read()
        
        # Crear el objeto BeautifulSoup
        soup = bs(html_content, "lxml")
        
        # Buscar el contenedor principal
        main_content = soup.select_one('section.re-SearchResult')
        if not main_content:
            print(f"No se encontró el contenedor principal en el archivo: {archivo}")
            continue

        # Clases principales y sus contenedores info correspondientes
        classes = {
            're-CardPackPremium': 're-CardPackPremium-info-container',
            're-CardPackAdvance': 're-CardPackAdvance-info-container',
            're-CardPackAdvanceNewConstruction.re-CardPackAdvanceNewConstruction--newConstruction': 're-CardPackAdvanceNewConstruction-info-container',
            're-CardPackBasic': 're-CardPackBasic-info-container',
        }

        # Iterar sobre cada clase principal y su respectivo contenedor info
        for main_class, info_class in classes.items():
            # Buscar todos los artículos de la clase principal
            articles = main_content.select(f'article.{main_class}')
            if not articles:
                print(f"No se encontró el articulo {main_class}")
                continue

            print(f"-------------> Procesando clase: {main_class}, total artículos encontrados: {len(articles)}")

            # Iterar sobre cada artículo
            for article_index, article in enumerate(articles, start=1):
                # Verificar si el contenedor info existe dentro del artículo
                print(f"Artículo {article_index} de la clase {main_class}...")
                info_containers = article.select(f'a.{info_class}')
                
                if not info_containers:
                    print(f"No se encontró '{info_class}' en artículo {article_index} de la clase {main_class}")
                    continue
                
                print("Info container:", info_class)

                # Extraer información de cada contenedor info
                for container_index, info_container in enumerate(info_containers, start=1):
                    # Extraer datos relevantes
                    precio = None
                    tipo_vivienda = None
                    titulo = None
                    calle = None
                    barrio = None
                    municipio = None
                    habitaciones = None
                    aseos = None
                    metros_cuadrados = None
                    planta = None
                    descripcion = None
                    etiquetas = []
                    garaje = "No"

                    # Precio
                    precio_element = info_container.select_one('span.re-CardPrice')
                    precio = precio_element.get_text(strip=True) if precio_element else None
                    precio = re.sub(r'[^\d]', '', precio) if precio else None
                    
                    # Título, calle, barrio y municipio
                    enlace_element = info_container.get('title', '').strip()
                    titulo = enlace_element if enlace_element else None

                    # Extraer calle y barrio del título
                    if ',' in titulo:  # Si hay comas en el título
                        partes = [parte.strip() for parte in titulo.split(',')]  # Dividir por comas y eliminar espacios
                        calle = partes[0] if len(partes) > 0 else None  # La primera parte es la calle
                        barrio = partes[-1] if len(partes) > 1 else None  # El último elemento es el barrio
                    else:  # Si no hay comas
                        palabras = titulo.split()  # Dividir el título por espacios
                        if len(palabras) > 2:  # Si hay más de dos palabras
                            calle = ' '.join(palabras[:-2])  # Todo excepto las dos últimas palabras como calle
                            barrio = ' '.join(palabras[-2:])  # Las dos últimas palabras como barrio
                        else:  # Si hay dos palabras o menos
                            calle = None  # No hay suficiente información para la calle
                            barrio = ' '.join(palabras)  # Tomar todo como barrio

                    municipio = "Manises"

                    # Tipo de vivienda
                    tipo_vivienda_element = info_container.select_one('h3.re-CardHeader strong')
                    tipo_vivienda = tipo_vivienda_element.get_text(strip=True) if tipo_vivienda_element else None

                    if tipo_vivienda:
                        if "obra" in tipo_vivienda.lower():
                            tipo_vivienda = "Piso"
                        elif 'piso' in tipo_vivienda.lower() or 'apartamento' in tipo_vivienda.lower():
                            tipo_vivienda = 'Piso'
                        elif 'atico' in tipo_vivienda.lower() or 'ático' in tipo_vivienda.lower():
                            tipo_vivienda = 'Piso'
                        elif 'duplex' in tipo_vivienda.lower() or 'dúplex' in tipo_vivienda.lower():
                            tipo_vivienda = 'Piso'
                        elif 'casa o chalet' in tipo_vivienda.lower() and "el mercado" in barrio.lower() or "centro ciudad" in barrio.lower() or "el carmen" in barrio.lower():
                            tipo_vivienda = 'Casa'
                        elif 'casa o chalet' in tipo_vivienda.lower():
                            tipo_vivienda = 'Chalet'
                        elif 'finca' in tipo_vivienda.lower() and "el mercado" in barrio.lower() or "centro ciudad" in barrio.lower() or "el carmen" in barrio.lower():
                            tipo_vivienda = 'Casa'
                        elif 'finca' in tipo_vivienda.lower():
                            tipo_vivienda = 'Finca'
                        else:
                            tipo_vivienda = tipo_vivienda

                    # Habitaciones, baños, metros cuadrados, planta y etiquetas
                    detalles = info_container.select('li.re-CardFeaturesWithIcons-feature')
                    for detalle in detalles:
                        texto = detalle.get_text(strip=True)
                        print(texto)
                        if "habs" in texto:
                            habitaciones = re.sub(r'[^\d]', '', texto)
                        elif "baño" in texto:
                            aseos = re.sub(r'[^\d]', '', texto)
                        elif "m²" in texto:
                            metros_cuadrados = re.sub(r'[^\d]', '', texto)
                        elif "Planta" in texto or "planta" in texto:
                            planta = texto
                        else:
                            etiquetas.append(texto)

                    # Descripción
                    #descripcion_element = info_container.select_one('
                    # p.re-CardDescription.re-CardDescription--isTwoLines > span.re-CardDescription-text.re-CardDescription-text--isTwoLines'
                    # )
                    
                    # Modificar el selector para abarcar ambas clases
                    descripcion_element = info_container.select_one(
                        'p.re-CardDescription.re-CardDescription--isTwoLines > span.re-CardDescription-text, '
                        'p.re-CardDescription.re-CardDescription--isOnelineShort > span.re-CardDescription-text'
                        )
                    descripcion = descripcion_element.get_text(strip=True) if descripcion_element else None

                    if descripcion:
                        print("Descripcion:", descripcion[:35])

                    # Garaje (inferir si está en la descripción o etiquetas)
                    garaje = "Sí" if descripcion and "garaje" in descripcion.lower() or any("garaje" in e.lower() for e in etiquetas) else "No"

                    # Almacenar los datos en un diccionario
                    datos_vivienda = {
                        'calle': calle,
                        'barrio': barrio,
                        'municipio': municipio,
                        'tipo_vivienda': tipo_vivienda,
                        'titulo': titulo,
                        'habitaciones': habitaciones,
                        'metros_cuadrados': metros_cuadrados,
                        'aseos': aseos,
                        'planta': planta,
                        'descripcion': descripcion,
                        'etiquetas': etiquetas,
                        'garaje': garaje,
                        'precio': precio
                    }
                    # Agregar los datos a la lista
                    datos_todas_viviendas.append(datos_vivienda)
                    print("\n")

# Crear un DataFrame consolidado
fotocasa1 = pd.DataFrame(datos_todas_viviendas)

# Convertir las columnas a tipo numérico
fotocasa1['precio'] = pd.to_numeric(fotocasa1['precio'], errors='coerce')
fotocasa1['habitaciones'] = pd.to_numeric(fotocasa1['habitaciones'], errors='coerce')
fotocasa1['aseos'] = pd.to_numeric(fotocasa1['aseos'], errors='coerce')
fotocasa1['metros_cuadrados'] = pd.to_numeric(fotocasa1['metros_cuadrados'], errors='coerce')

# Mostrar los primeros resultados
print(fotocasa1.shape)
fotocasa1.head(2)
# Out:
# >>>>>>>>>>>>>> fotocasa1.txt <<<<<<<<<<<<<<
# No se encontró el articulo re-CardPackPremium
# No se encontró el articulo re-CardPackAdvance
# No se encontró el articulo re-CardPackAdvanceNewConstruction.re-CardPackAdvanceNewConstruction--newConstruction
# No se encontró el articulo re-CardPackBasic
#
# >>>>>>>>>>>>>> fotocasa10.txt <<<<<<<<<<<<<<
# No se encontró el articulo re-CardPackPremium
# No se encontró el articulo re-CardPackAdvance
# No se encontró el articulo re-CardPackAdvanceNewConstruction.re-CardPackAdvanceNewConstruction--newConstruction
# No se encontró el articulo re-CardPackBasic
#
# >>>>>>>>>>>>>> fotocasa11.txt <<<<<<<<<<<<<<
# No se encontró el articulo re-CardPackPremium
# No se encontró el articulo re-CardPackAdvance
# No se encontró el articulo re-CardPackAdvanceNewConstruction.re-CardPackAdvanceNewConstruction--newConstruction
# No se encontró el articulo re-CardPackBasic
#
# >>>>>>>>>>>>>> fotocasa12.txt <<<<<<<<<<<<<<
# No se encontró el articulo re-CardPackPremium
# No se encontró el articulo re-CardPackAdvance
# No se encontró el articulo re-CardPackAdvanceNewConstruction.re-CardPackAdvanceNewConstruction--newConstruction
# No se encontró el articulo re-CardPackBasic
#
# >>>>>>>>>>>>>> fotocasa13.txt <<<<<<<<<<<<<<
# No se encontró el articulo re-CardPackPremium
# No se encontró el articulo re-CardPackAdvance
# No se encontró el articulo re-CardPackAdvanceNewConstruction.re-CardPackAdvanceNewConstruction--newConstruction
# No se encontró el articulo re-CardPackBasic
#
# >>>>>>>>>>>>>> fotocasa14.txt <<<<<<<<<<<<<<
# No se encontró el articulo re-CardPackPremium
# No se encontró el articulo re-CardPackAdvance
# No se encontró el articulo re-CardPackAdvanceNewConstruction.re-CardPackAdvanceNewConstruction--newConstruction
# -------------> Procesando clase: re-CardPackBasic, total artículos encontrados: 6
# Artículo 1 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 414 m²
# Descripcion: Espectacular CASA de pueblo con una
#
#
# Artículo 2 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 2 habs.
# 1 baño
# 53 m²
# Descripcion: Sin comisiones de agencia. Piso ubi
#
#
# Artículo 3 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 4 habs.
# 1 baño
# 190 m²
# Descripcion: VIVIENDA EN PLANTA BAJA JUNTO CON P
#
#
# Artículo 4 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 73 m²
# Descripcion: Casa unifamiliar para reformar. Cue
#
#
# Artículo 5 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 6 habs.
# 2 baños
# 825 m²
# Descripcion: Exclusiva casa señorial ubicada en
#
#
# Artículo 6 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 3 habs.
# 1 baño
# 85 m²
# Descripcion: Piso en venta en Aldaia. Oportunida
#
#
#
# >>>>>>>>>>>>>> fotocasa15.txt <<<<<<<<<<<<<<
# No se encontró el articulo re-CardPackPremium
# -------------> Procesando clase: re-CardPackAdvance, total artículos encontrados: 5
# Artículo 1 de la clase re-CardPackAdvance...
# Info container: re-CardPackAdvance-info-container
# 4 habs.
# 1 baño
# 96 m²
# Descripcion: **¡Oportunidad única en el centro d
#
#
# Artículo 2 de la clase re-CardPackAdvance...
# Info container: re-CardPackAdvance-info-container
# 4 habs.
# 1 baño
# 218 m²
# Descripcion: Os presentamos esta oportunidad en
#
#
# Artículo 3 de la clase re-CardPackAdvance...
# Info container: re-CardPackAdvance-info-container
# 4 habs.
# 1 baño
# 120 m²
# Descripcion: REF 5910 piso en Manises en zona Ce
#
#
# Artículo 4 de la clase re-CardPackAdvance...
# Info container: re-CardPackAdvance-info-container
# 3 habs.
# 2 baños
# 115 m²
# Descripcion: Pisos de obra Nueva en Paterna a un
#
#
# Artículo 5 de la clase re-CardPackAdvance...
# Info container: re-CardPackAdvance-info-container
# 122 m²
# Descripcion: . Disponemos de esta casa solar sit
#
#
# -------------> Procesando clase: re-CardPackAdvanceNewConstruction.re-CardPackAdvanceNewConstruction--newConstruction, total artículos encontrados: 2
# Artículo 1 de la clase re-CardPackAdvanceNewConstruction.re-CardPackAdvanceNewConstruction--newConstruction...
# Info container: re-CardPackAdvanceNewConstruction-info-container
# 3 habs.
# 2 baños
# 104 m²
# Descripcion: NUEVA PROMOCIÓN. LANDCO MANISES III
#
#
# Artículo 2 de la clase re-CardPackAdvanceNewConstruction.re-CardPackAdvanceNewConstruction--newConstruction...
# Info container: re-CardPackAdvanceNewConstruction-info-container
# 4 habs.
# 2 baños
# 147 m²
# Descripcion: NUEVA PROMOCIÓN. LANDCO MANISES III
#
#
# -------------> Procesando clase: re-CardPackBasic, total artículos encontrados: 23
# Artículo 1 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 3 habs.
# 2 baños
# 85 m²
# Descripcion: ¡No pierdas la oportunidad de vivir
#
#
# Artículo 2 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 2 habs.
# 1 baño
# 134 m²
# Descripcion: Este casa a reformar se encuentra e
#
#
# Artículo 3 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 550 m²
# Descripcion: Casa independiente para derribar Si
#
#
# Artículo 4 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 4 habs.
# 1 baño
# 322 m²
# Descripcion: Os presentamos esta casa de campo c
#
#
# Artículo 5 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 3 habs.
# 1 baño
# 201 m²
# Descripcion: Esta impresionante propiedad ofrece
#
#
# Artículo 6 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 8 habs.
# 3 baños
# 743 m²
# Descripcion: Venta de uno de los más exclusivos
#
#
# Artículo 7 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 4 habs.
# 1 baño
# 89 m²
# Descripcion: Quatre Torres dispone a la venta en
#
#
# Artículo 8 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 4 habs.
# 2 baños
# 93 m²
# Descripcion: Si quieres vivir en el centro de Pa
#
#
# Artículo 9 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 3 habs.
# 1 baño
# 85 m²
# Descripcion: Presentamos un atractivo piso dispo
#
#
# Artículo 10 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 3 habs.
# 1 baño
# 60 m²
# Descripcion: **Oportunidad Única: ATICO  en Vent
#
#
# Artículo 11 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 1 hab.
# 1 baño
# 65 m²
# Descripcion: Este encantador ático de 65 m², sit
#
#
# Artículo 12 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 2 habs.
# 1 baño
# 92 m²
# Descripcion: Piso con terraza en edificio histór
#
#
# Artículo 13 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 4 habs.
# 2 baños
# 156 m²
# Descripcion: ¡Tu nuevo hogar en el corazón de la
#
#
# Artículo 14 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 2 habs.
# 1 baño
# 92 m²
# Descripcion: " " " " " Grupo Inmobiliario Sellin
#
#
# Artículo 15 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 3 habs.
# 2 baños
# 104 m²
# Descripcion: Vivienda  localizada en Manises, Va
#
#
# Artículo 16 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 4 habs.
# 1 baño
# 96 m²
# Descripcion: Amplio piso con balcón y dos terraz
#
#
# Artículo 17 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 5 habs.
# 3 baños
# 352 m²
# Descripcion: Casa urbana con garaje y varias ter
#
#
# Artículo 18 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 3 habs.
# 1 baño
# 95 m²
# Descripcion: Piso muy luminoso en pleno centro d
#
#
# Artículo 19 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 4 habs.
# 1 baño
# 105 m²
# Descripcion: Cerca del centro de la cañada encon
#
#
# Artículo 20 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 5 habs.
# 2 baños
# 216 m²
# Descripcion: Chalet adosado en La Cañada de 5 do
#
#
# Artículo 21 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 2 habs.
# 2 baños
# 105 m²
# Descripcion: ATHIKA presenta. ¡Oportunidad única
#
#
# Artículo 22 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 3 habs.
# 2 baños
# 94 m²
# Descripcion: ATHIKA presenta en exclusiva. ¡Opor
#
#
# Artículo 23 de la clase re-CardPackBasic...
# Info container: re-CardPackBasic-info-container
# 3 habs.
# 1 baño
# 85 m²
# Descripcion: Chalet en venta en la localidad de
#
#
#
# >>>>>>>>>>>>>> fotocasa16.txt <<<<<<<<<<<<<<
# -------------> Procesando clase: re-CardPackPremium, total artículos encontrados: 22
# Artículo 1 de la clase re-CardPackPremium...
# Info container: re-CardPackPremium-info-container
# 2 habs.
# 1 baño
# 61 m²
# Bajos
# Descripcion: SIN COMISION INMOBILIARIA.
# Vivienda
#
#
# Artículo 2 de la clase re-CardPackPremium...
# Info container: re-CardPackPremium-info-container
# 3 habs.
# 1 baño
# 72 m²
# 5ª Planta
# Ascensor
# Aire acondicionado
# Descripcion: Fantástica vivienda en el corazón d
#
#
# Artículo 3 de la clase re-CardPackPremium...
# Info container: re-CardPackPremium-info-container
# 5 habs.
# 3 baños
# 291 m²
# Parking
# Descripcion: ¡Exclusiva oportunidad en La Cañada
#
#
# Artículo 4 de la clase re-CardPackPremium...
# Info container: re-CardPackPremium-info-container
# 4 habs.
# 1 baño
# 132 m²
# 1ª Planta
# Ascensor
# Balcón
# Descripcion: Piso en venta en Paterna, zona cent
#
#
# Artículo 5 de la clase re-CardPackPremium...
# Info container: re-CardPackPremium-info-container
# 4 habs.
# 1 baño
# 89 m²
# 4ª Planta
# Balcón
# Calefacción
# Descripcion: Estupendo piso en Paterna, zona de
#
#
# Artículo 6 de la clase re-CardPackPremium...
# Info container: re-CardPackPremium-info-container
# 3 habs.
# 3 baños
# 130 m²
# Terraza
# Descripcion: VIVIENDA SUPER CUQUI A ESTRENAR.
#
# U
#
#
# Artículo 7 de la clase re-CardPackPremium...
# Info container: re-CardPackPremium-info-container
# 6 habs.
# 4 baños
# 487 m²
# Parking
# Terraza
# Aire acondicionado
# Descripcion: En una de las zonas más demandadas
#
#
# Artículo 8 de la clase re-CardPackPremium...
# Info container: re-CardPackPremium-info-container
# 4 habs.
# 1 baño
# 93 m²
# 3ª Planta
# Ascensor
# Balcón
# Descripcion: 008MAY142. EXTERIOR CON BALCÓN Y AS
#
#
# Artículo 9 de la clase re-CardPackPremium...
# Info container: re-CardPackPremium-info-container
# 5 habs.
# 2 baños
# 164 m²
# Ascensor
# Parking
# Terraza
# Descripcion: Engel & Völkers presenta en exclusi
#
#
# Artículo 10 de la clase re-CardPackPremium...
# Info container: re-CardPackPremium-info-container
# 4 habs.
# 1 baño
# 73 m²
# 5ª Planta
# Balcón
# Descripcion: 007RBO109 EXTERIOR CON BALCÓN JUNTO
#
#
# Artículo 11 de la clase re-CardPackPremium...
# Info container: re-CardPackPremium-info-container
# 4 habs.
# 2 baños
# 356 m²
# Terraza
# Piscina
# Balcón
# Descripcion: ( Ref. HH-2529 )
#
# ESTUPENDO CHALET
#
#
# Artículo 12 de la clase re-CardPackPremium...
# Info container: re-CardPackPremium-info-container
# 3 habs.
# 2 baños
# 133 m²
# Parking
# Terraza
# Calefacción
# Descripcion: Esta preciosa propiedad recién refo
#
#
# Artículo 13 de la clase re-CardPackPremium...
# Info container: re-CardPackPremium-info-container
# 5 habs.
# 2 baños
# 216 m²
# Parking
# Terraza
# Balcón
# Descripcion: ART INMOBILIARIA GESTIONA LA VENTA
#
#
# Artículo 14 de la clase re-CardPackPremium...
# Info container: re-CardPackPremium-info-container
# 4 habs.
# 1 baño
# 89 m²
# 4ª Planta
# Balcón
# Calefacción
# Descripcion: Estupendo piso en Paterna, zona de
#
#
# Artículo 15 de la clase re-CardPackPremium...
# Info container: re-CardPackPremium-info-container
# 6 habs.
# 3 baños
# 212 m²
# Parking
# Terraza
# Piscina
# Descripcion: Chalet independiente en El Plantío
#
#
# Artículo 16 de la clase re-CardPackPremium...
# Info container: re-CardPackPremium-info-container
# 10 habs.
# 11 baños
# 800 m²
# Parking
# Terraza
# Piscina
# Descripcion: MASÍA CON LICENCIA TURÍSTICA EN MAN
#
#
# Artículo 17 de la clase re-CardPackPremium...
# Info container: re-CardPackPremium-info-container
# 5 habs.
# 4 baños
# 261 m²
# Parking
# Terraza
# Piscina
# Descripcion: Ubicado en la zona privilegiada de
#
#
# Artículo 18 de la clase re-CardPackPremium...
# Info container: re-CardPackPremium-info-container
# 5 habs.
# 4 baños
# 572 m²
# Parking
# Terraza
# Balcón
# Descripcion: Vivienda unifamiliar con una superf
#
#
# Artículo 19 de la clase re-CardPackPremium...
# Info container: re-CardPackPremium-info-container
# 5 habs.
# 2 baños
# 145 m²
# Bajos
# Terraza
# Aire acondicionado
# Descripcion: ( Ref. HH-3049 )
#
# Si buscas una viv
#
#
# Artículo 20 de la clase re-CardPackPremium...
# Info container: re-CardPackPremium-info-container
# 3 habs.
# 2 baños
# 98 m²
# Terraza
# Descripcion: ¡Preciosa casa completa con gran co
#
#
# Artículo 21 de la clase re-CardPackPremium...
# Info container: re-CardPackPremium-info-container
# 4 habs.
# 2 baños
# 144 m²
# Parking
# Terraza
# Piscina
# Descripcion: ART INMOBILIARIA VENDE MODERNO CHAL
#
#
# Artículo 22 de la clase re-CardPackPremium...
# Info container: re-CardPackPremium-info-container
# 3 habs.
# 1 baño
# 204 m²
# Descripcion: Esta espaciosa casa en venta se enc
#
#
# -------------> Procesando clase: re-CardPackAdvance, total artículos encontrados: 6
# Artículo 1 de la clase re-CardPackAdvance...
# Info container: re-CardPackAdvance-info-container
# 3 habs.
# 1 baño
# 85 m²
# Descripcion: Pisos de obra Nueva en Paterna a un
#
#
# Artículo 2 de la clase re-CardPackAdvance...
# Info container: re-CardPackAdvance-info-container
# 122 m²
# Terraza
# Descripcion: REF 01100 SE VENDE CASA EN LA ZONA
#
#
# Artículo 3 de la clase re-CardPackAdvance...
# Info container: re-CardPackAdvance-info-container
# 5 habs.
# 2 baños
# 216 m²
# Descripcion: Agradable adosado  en La Cañada,  e
#
#
# Artículo 4 de la clase re-CardPackAdvance...
# Info container: re-CardPackAdvance-info-container
# 3 habs.
# 3 baños
# 311 m²
# Descripcion: Exclusiva casa independiente con ex
#
#
# Artículo 5 de la clase re-CardPackAdvance...
# Info container: re-CardPackAdvance-info-container
# 2 habs.
# 1 baño
# 73 m²
# Descripcion: Se vende piso en el barrio de Santa
#
#
# Artículo 6 de la clase re-CardPackAdvance...
# Info container: re-CardPackAdvance-info-container
# 6 habs.
# 4 baños
# 521 m²
# Descripcion: One SAB Inmobiliaria presenta espec
#
#
# -------------> Procesando clase: re-CardPackAdvanceNewConstruction.re-CardPackAdvanceNewConstruction--newConstruction, total artículos encontrados: 2
# Artículo 1 de la clase re-CardPackAdvanceNewConstruction.re-CardPackAdvanceNewConstruction--newConstruction...
# Info container: re-CardPackAdvanceNewConstruction-info-container
# 2 habs.
# 2 baños
# 78 m²
# Descripcion: NUEVA PROMOCIÓN. LANDCO MANISES III
#
#
# Artículo 2 de la clase re-CardPackAdvanceNewConstruction.re-CardPackAdvanceNewConstruction--newConstruction...
# Info container: re-CardPackAdvanceNewConstruction-info-container
# 3 habs.
# 2 baños
# 116 m²
# Descripcion: Atalanta, un nombre impregnado de h
#
#
# No se encontró el articulo re-CardPackBasic
#
# >>>>>>>>>>>>>> fotocasa2.txt <<<<<<<<<<<<<<
# No se encontró el articulo re-CardPackPremium
# No se encontró el articulo re-CardPackAdvance
# No se encontró el articulo re-CardPackAdvanceNewConstruction.re-CardPackAdvanceNewConstruction--newConstruction
# No se encontró el articulo re-CardPackBasic
#
# >>>>>>>>>>>>>> fotocasa3.txt <<<<<<<<<<<<<<
# No se encontró el articulo re-CardPackPremium
# No se encontró el articulo re-CardPackAdvance
# No se encontró el articulo re-CardPackAdvanceNewConstruction.re-CardPackAdvanceNewConstruction--newConstruction
# No se encontró el articulo re-CardPackBasic
#
# >>>>>>>>>>>>>> fotocasa4.txt <<<<<<<<<<<<<<
# No se encontró el articulo re-CardPackPremium
# No se encontró el articulo re-CardPackAdvance
# No se encontró el articulo re-CardPackAdvanceNewConstruction.re-CardPackAdvanceNewConstruction--newConstruction
# No se encontró el articulo re-CardPackBasic
#
# >>>>>>>>>>>>>> fotocasa5.txt <<<<<<<<<<<<<<
# No se encontró el articulo re-CardPackPremium
# No se encontró el articulo re-CardPackAdvance
# No se encontró el articulo re-CardPackAdvanceNewConstruction.re-CardPackAdvanceNewConstruction--newConstruction
# No se encontró el articulo re-CardPackBasic
#
# >>>>>>>>>>>>>> fotocasa6.txt <<<<<<<<<<<<<<
# No se encontró el articulo re-CardPackPremium
# No se encontró el articulo re-CardPackAdvance
# No se encontró el articulo re-CardPackAdvanceNewConstruction.re-CardPackAdvanceNewConstruction--newConstruction
# No se encontró el articulo re-CardPackBasic
#
# >>>>>>>>>>>>>> fotocasa7.txt <<<<<<<<<<<<<<
# No se encontró el articulo re-CardPackPremium
# No se encontró el articulo re-CardPackAdvance
# No se encontró el articulo re-CardPackAdvanceNewConstruction.re-CardPackAdvanceNewConstruction--newConstruction
# No se encontró el articulo re-CardPackBasic
#
# >>>>>>>>>>>>>> fotocasa8.txt <<<<<<<<<<<<<<
# No se encontró el articulo re-CardPackPremium
# No se encontró el articulo re-CardPackAdvance
# No se encontró el articulo re-CardPackAdvanceNewConstruction.re-CardPackAdvanceNewConstruction--newConstruction
# No se encontró el articulo re-CardPackBasic
#
# >>>>>>>>>>>>>> fotocasa9.txt <<<<<<<<<<<<<<
# No se encontró el articulo re-CardPackPremium
# No se encontró el articulo re-CardPackAdvance
# No se encontró el articulo re-CardPackAdvanceNewConstruction.re-CardPackAdvanceNewConstruction--newConstruction
# No se encontró el articulo re-CardPackBasic
# (66, 13)
#                                     calle      barrio municipio tipo_vivienda  \
# 0                  Casa o chalet en venta   en Aldaia   Manises        Chalet
# 1  Piso en venta en Santos Justo y Pastor  El Mercado   Manises          Piso
#
#                                               titulo  habitaciones  \
# 0                   Casa o chalet en venta en Aldaia           NaN
# 1  Piso en venta en Santos Justo y Pastor, El Mer...           2.0
#
#    metros_cuadrados  aseos planta  \
# 0               414    NaN   None
# 1                53    1.0   None
#
#                                          descripcion etiquetas garaje  precio
# 0  Espectacular CASA de pueblo con una ubicada PR...        []     No  230000
# 1  Sin comisiones de agencia. Piso ubicado en la ...        []     No   60000

# %% [markdown]
# #### Nos vamos a asegurar de que no **existen duplicados**, ya que hay muchos anuncios repetidos en la plataforma. Nos basaremos en específicas columnas importantes, ya que algunas son tipo lista y dan problemas a la hora de usar ***.drop_duplicates()***

# %%
print(f"Antes de eliminar duplicados: {fotocasa1.shape}")
fotocasa1 = fotocasa1.drop_duplicates(subset=['tipo_vivienda','habitaciones', 'metros_cuadrados', 'aseos', 'planta', 'garaje', 'precio'])
print(f"Después de eliminar duplicados: {fotocasa1.shape}")
# Out:
# Antes de eliminar duplicados: (66, 13)
# Después de eliminar duplicados: (62, 13)

# %%
fotocasa1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62 entries, 0 to 65
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   calle             62 non-null     object
#  1   barrio            62 non-null     object
#  2   municipio         62 non-null     object
#  3   tipo_vivienda     62 non-null     object
#  4   titulo            62 non-null     object
#  5   habitaciones      56 non-null     float64
#  6   metros_cuadrados  62 non-null     int64
#  7   aseos             57 non-null     float64
#  8   planta            5 non-null      object
#  9   descripcion       62 non-null     object
#  10  etiquetas         62 non-null     object
#  11  garaje            62 non-null     object
#  12  precio            62 non-null     int64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 6.8+ KB

# %%
# fotocasa1[fotocasa1["tipo_vivienda"].isna()]
# fotocasa1["barrio"].value_counts()
fotocasa1["tipo_vivienda"].value_counts()
# Out:
# tipo_vivienda
# Piso            28
# Chalet          22
# Casa adosada     4
# Casa             3
# Planta baja      3
# Finca            2
# Name: count, dtype: int64

# %% [markdown]
# ### **Segunda parte** del Webscrapping para fotocasa:

# %% [markdown]
# #### Etiquetas: **'re-CardPackMinimal', 're-CardPackMinimal--qualitySeal'**

# %%
# Ruta de la carpeta FOTOCASA que contiene el HTML
carpeta = "../data/raw/fotocasa"

# Lista para almacenar todos los datos de viviendas
datos_todas_viviendas = []

# Iterar sobre todos los archivos .txt en la carpeta
for archivo in os.listdir(carpeta):
    if archivo.endswith(".txt"):
        print("\n>>>>>>>>>>>>>>",archivo, "<<<<<<<<<<<<<<")
        ruta_archivo = os.path.join(carpeta, archivo)
        with open(ruta_archivo, 'r', encoding='utf-8') as file:
            html_content = file.read()
        
        # Crear el objeto BeautifulSoup
        soup = bs(html_content, "lxml")
        
        # Buscar el contenedor principal
        main_content = soup.select_one('section.re-SearchResult')
        if not main_content:
            print(f"No se encontró el contenedor principal en el archivo: {archivo}")
            continue

        # Clases principales y sus contenedores info correspondientes
        classes = {
            're-CardPackMinimal': 're-CardPackMinimal-info-container',
            're-CardPackMinimal--qualitySeal': 're-CardPackMinimal-info-container'
        }
        
        # Iterar sobre cada clase principal y su respectivo contenedor info
        for main_class, info_class in classes.items():
            # Buscar todos los artículos de la clase principal
            articles = main_content.select(f'article.{main_class}')
            if not articles:
                print(f"No se encontró el articulo {main_class}")
                continue

            print(f"-------------> Procesando clase: {main_class}, total artículos encontrados: {len(articles)}")
            
            # Iterar sobre cada artículo
            for article_index, article in enumerate(articles, start=1):
                print(f"Artículo {article_index} de la clase {main_class}...")

                info_containers = article.select(f"div.{main_class}-info > a.{info_class}")

                if not info_containers:
                    info_containers = article.select(f"a.{info_class}")

                    if not info_containers:
                        print(f"No se encontró '{info_class}' en artículo {article_index} de la clase {main_class}")
                        continue

                print("Info container:", info_class)

                # Extraer información de cada contenedor
                for container_index, info_container in enumerate(info_containers, start=1):
                    # Extraer datos relevantes
                    precio = None
                    tipo_vivienda = None
                    titulo = None
                    calle = None
                    barrio = None
                    municipio = None
                    habitaciones = None
                    aseos = None
                    metros_cuadrados = None
                    planta = None
                    descripcion = None
                    etiquetas = []
                    garaje = "No"

                    # Precio
                    precio_element = info_container.select_one('span.re-CardPrice')
                    precio = precio_element.get_text(strip=True) if precio_element else None
                    precio = re.sub(r'[^\d]', '', precio) if precio else None

                    # Título, calle, barrio y municipio
                    enlace_element = info_container.get('title', '').strip()
                    titulo = enlace_element if enlace_element else None

                    # Extraer calle y barrio del título
                    if ',' in titulo:  # Si hay comas en el título
                        partes = [parte.strip() for parte in titulo.split(',')]  # Dividir por comas y eliminar espacios
                        calle = partes[0] if len(partes) > 0 else None  # La primera parte es la calle
                        barrio = partes[-1] if len(partes) > 1 else None  # El último elemento es el barrio
                    else:  # Si no hay comas
                        palabras = titulo.split()  # Dividir el título por espacios
                        if len(palabras) > 2:  # Si hay más de dos palabras
                            calle = ' '.join(palabras[:-2])  # Todo excepto las dos últimas palabras como calle
                            barrio = ' '.join(palabras[-2:])  # Las dos últimas palabras como barrio
                        else:  # Si hay dos palabras o menos
                            calle = None  # No hay suficiente información para la calle
                            barrio = ' '.join(palabras)  # Tomar todo como barrio

                    municipio = "Manises"

                    # Tipo de vivienda
                    tipo_vivienda_element = info_container.select_one('h3.re-CardHeader strong')
                    tipo_vivienda = tipo_vivienda_element.get_text(strip=True) if tipo_vivienda_element else None
                    
                    if tipo_vivienda:
                        if "obra" in tipo_vivienda.lower():
                            tipo_vivienda = "Piso"
                        elif 'piso' in tipo_vivienda.lower() or 'apartamento' in tipo_vivienda.lower():
                            tipo_vivienda = 'Piso'
                        elif 'atico' in tipo_vivienda.lower() or 'ático' in tipo_vivienda.lower():
                            tipo_vivienda = 'Piso'
                        elif 'duplex' in tipo_vivienda.lower() or 'dúplex' in tipo_vivienda.lower():
                            tipo_vivienda = 'Piso'
                        elif 'casa o chalet' in tipo_vivienda.lower() and "el mercado" in barrio.lower() or "centro ciudad" in barrio.lower() or "el carmen" in barrio.lower():
                            tipo_vivienda = 'Casa'
                        elif 'casa o chalet' in tipo_vivienda.lower():
                            tipo_vivienda = 'Chalet'
                        elif 'finca' in tipo_vivienda.lower() and "el mercado" in barrio.lower() or "centro ciudad" in barrio.lower() or "el carmen" in barrio.lower():
                            tipo_vivienda = 'Casa'
                        elif 'finca' in tipo_vivienda.lower():
                            tipo_vivienda = 'Finca'
                        else:
                            tipo_vivienda = tipo_vivienda

                    # Habitaciones, baños, metros cuadrados, planta y etiquetas
                    detalles = info_container.select('li.re-CardFeatures-item.re-CardFeatures-feature')
                    for detalle in detalles:
                        texto = detalle.get_text(strip=True)
                        print(texto)
                        if "habs" in texto:
                            habitaciones = re.sub(r'[^\d]', '', texto)
                        elif "baño" in texto:
                            aseos = re.sub(r'[^\d]', '', texto)
                        elif "m²" in texto:
                            metros_cuadrados = re.sub(r'[^\d]', '', texto)
                        elif "Planta" in texto or "planta" in texto:
                            planta = texto
                        else:
                            etiquetas.append(texto)

                    # Descripción
                    descripcion_element = info_container.select_one('p.re-CardDescription.re-CardDescription--isTwoLines > span.re-CardDescription-text.re-CardDescription-text--isTwoLines')

                    descripcion = descripcion_element.get_text(strip=True) if descripcion_element else None

                    if descripcion:
                        print("Descripcion:", descripcion[:35])
                    
                    # Garaje (inferir si está en la descripción o etiquetas)
                    garaje = "Sí" if descripcion and "garaje" in descripcion.lower() or any("garaje" in e.lower() for e in etiquetas) else "No"

                    # Almacenar los datos en un diccionario
                    datos_vivienda = {
                        'calle': calle,
                        'barrio': barrio,
                        'municipio': municipio,
                        'tipo_vivienda': tipo_vivienda,
                        'titulo': titulo,
                        'habitaciones': habitaciones,
                        'metros_cuadrados': metros_cuadrados,
                        'aseos': aseos,
                        'planta': planta,
                        'descripcion': descripcion,
                        'etiquetas': etiquetas,
                        'garaje': garaje,
                        'precio': precio
                    }
                    # Agregar los datos a la lista
                    datos_todas_viviendas.append(datos_vivienda)
                    print("\n")

# Crear un DataFrame consolidado
fotocasa2 = pd.DataFrame(datos_todas_viviendas)

# Convertir las columnas a tipo numérico
fotocasa2['precio'] = pd.to_numeric(fotocasa2['precio'], errors='coerce')
fotocasa2['habitaciones'] = pd.to_numeric(fotocasa2['habitaciones'], errors='coerce')
fotocasa2['aseos'] = pd.to_numeric(fotocasa2['aseos'], errors='coerce')
fotocasa2['metros_cuadrados'] = pd.to_numeric(fotocasa2['metros_cuadrados'], errors='coerce')

# Mostrar los primeros resultados
print(fotocasa2.shape)
fotocasa2.head(2)
# Out:
# >>>>>>>>>>>>>> fotocasa1.txt <<<<<<<<<<<<<<
# -------------> Procesando clase: re-CardPackMinimal, total artículos encontrados: 30
# Artículo 1 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 2 baños
# 80 m²
# Ascensor
# Terraza
# Descripcion: REF 2534 Se vende  magnifica vivien
#
#
# Artículo 2 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 150 m²
# 3ª Planta
# Ascensor
# Descripcion: Piso  en ALDAIA - BARRIO DEL CRISTO
#
#
# Artículo 3 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 3 baños
# 280 m²
# Parking
# Aire acondicionado
# Descripcion: CASA O CHALET EN VENTA EN CALLE CON
#
#
# Artículo 4 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 96 m²
# 1ª Planta
# Terraza
# Descripcion: ¡Oportunidad única en el corazón de
#
#
# Artículo 5 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 3 baños
# 343 m²
# Terraza
# Balcón
# Descripcion: Estupenda casa en zona centro del P
#
#
# Artículo 6 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 3 baños
# 175 m²
# Parking
# Terraza
# Descripcion: Adosado espectacular en Manises, 17
#
#
# Artículo 7 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 200 m²
# Terraza
# Piscina
# Descripcion: Estupendo chalet urbano de unos 145
#
#
# Artículo 8 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 213 m²
# Terraza
# Piscina
# Descripcion: Estupendo Chalet en la Malla para v
#
#
# Artículo 9 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 230 m²
# Parking
# Calefacción
# Descripcion: ´Vivienda independiente, cómoda y m
#
#
# Artículo 10 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 126 m²
# Descripcion: Casa de pueblo para derribar de uno
#
#
# Artículo 11 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 95 m²
# 1ª Planta
# Terraza
# Descripcion: Venta de piso en Manises, zona Merc
#
#
# Artículo 12 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 3 baños
# 527 m²
# Parking
# Terraza
# Descripcion: CREA ESPACIO RESIDENCIAL, presenta
#
#
# Artículo 13 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 125 m²
# Ascensor
# Parking
# Descripcion: PISO DE 3 HABITACIONES CON ASCENSOR
#
#
# Artículo 14 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 3 baños
# Parking
# Terraza
# Balcón
# Descripcion: Creaespacio Residencial presenta es
#
#
# Artículo 15 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 4 baños
# 310 m²
# Parking
# Terraza
# Descripcion: Creaespacio residencial les present
#
#
# Artículo 16 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 3 baños
# 527 m²
# Parking
# Terraza
# Descripcion: CREA ESPACIO RESIDENCIAL, presenta
#
#
# Artículo 17 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 380 m²
# Terraza
# Balcón
# Descripcion: Casa en zona muy tranquila de Manis
#
#
# Artículo 18 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 230 m²
# Descripcion: JUNTO AYUNTAMIENTO. Centro junto ay
#
#
# Artículo 19 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 200 m²
# Parking
# Terraza
# Descripcion: Esta espaciosa casa en venta se enc
#
#
# Artículo 20 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 2 baños
# 122 m²
# Ascensor
# Terraza
# Descripcion: ✨ Características principales:
# 🏠 12
#
#
# Artículo 21 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 213 m²
# Piscina
# Descripcion: ¡Descubre el hogar de tus sueños en
#
#
# Artículo 22 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 74 m²
# 3ª Planta
# Balcón
# Descripcion: Vivienda situada en CALLE MAESTRO A
#
#
# Artículo 23 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 68 m²
# 3ª Planta
# Balcón
# Descripcion: ** OPTIMUS INMOBILIARIA te presenta
#
#
# Artículo 24 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 3 baños
# 304 m²
# Parking
# Terraza
# Descripcion: Vivienda situada en CALLE SANT ROC,
#
#
# Artículo 25 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 64 m²
# 1ª Planta
# Balcón
# Descripcion: Vivienda situada en Calle LA MERCE
#
#
# Artículo 26 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 105 m²
# 2ª Planta
# Ascensor
# Descripcion: Vivienda situada en Calle  Pins Del
#
#
# Artículo 27 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 3 baños
# 402 m²
# Parking
# Terraza
# Descripcion: Vivienda situada en Calle 361, en P
#
#
# Artículo 28 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 140 m²
# Descripcion: Venta de casa en Manises, zona casc
#
#
# Artículo 29 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 371 m²
# Descripcion: PATERNA (Valencia). SIN POSESIÓN (n
#
#
# Artículo 30 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 67 m²
# 4ª Planta
# Descripcion: INVERSORES - CESIÓN DE REMATE. El i
#
#
# No se encontró el articulo re-CardPackMinimal--qualitySeal
#
# >>>>>>>>>>>>>> fotocasa10.txt <<<<<<<<<<<<<<
# -------------> Procesando clase: re-CardPackMinimal, total artículos encontrados: 30
# Artículo 1 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 64 m²
# 5ª Planta
# Balcón
# Descripcion: REF 5933 piso en Manises en zona El
#
#
# Artículo 2 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 6 habs.
# 4 baños
# 550 m²
# Parking
# Terraza
# Descripcion: Sobre una parcela de mas de 2200m2
#
#
# Artículo 3 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 100 m²
# Aire acondicionado
# Descripcion: ¡Descubre tu nuevo hogar en este en
#
#
# Artículo 4 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 78 m²
# Terraza
# Calefacción
# Descripcion: Agencia Mediterránea tiene el place
#
#
# Artículo 5 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 3 baños
# 202 m²
# Parking
# Terraza
# Descripcion: ENTER PROPERTIES os presenta este c
#
#
# Artículo 6 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 160 m²
# Parking
# Terraza
# Descripcion: ¡Bienvenidos a este bonito chalet e
#
#
# Artículo 7 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 1 hab.
# 1 baño
# 85 m²
# Ascensor
# Terraza
# Descripcion: Loft-Oficina en planta 1ª  con asce
#
#
# Artículo 8 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 120 m²
# 1ª Planta
# Terraza
# Descripcion: JTM Dreams les presenta esta fantás
#
#
# Artículo 9 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 88 m²
# Terraza
# Calefacción
# Descripcion: Athika presenta. Finca rustica con
#
#
# Artículo 10 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 64 m²
# 5ª Planta
# Balcón
# Descripcion: ¡Oportunidad en venta! Piso en el c
#
#
# Artículo 11 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 120 m²
# 1ª Planta
# Terraza
# Descripcion: Este encantador piso de 4 dormitori
#
#
# Artículo 12 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 96 m²
# 1ª Planta
# Balcón
# Descripcion: ARKIA Inmuebles & Arquitectura te o
#
#
# Artículo 13 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 90 m²
# Bajos
# Terraza
# Descripcion: Vivienda en planta baja en edificio
#
#
# Artículo 14 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 98 m²
# 3ª Planta
# Ascensor
# Descripcion: Piso de 3 habitaciones, dos cuartos
#
#
# Artículo 15 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 5 baños
# 586 m²
# Parking
# Terraza
# Descripcion: Vivienda de espacios amplios distri
#
#
# Artículo 16 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 48 m²
# 3ª Planta
# Calefacción
# Descripcion: En venta con un buen inquilino, ide
#
#
# Artículo 17 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 3 baños
# 452 m²
# Parking
# Terraza
# Descripcion: En venta magnífico chalet independi
#
#
# Artículo 18 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 2 baños
# 216 m²
# Parking
# Terraza
# Descripcion: Vivienda adosada en La Cañada, ubic
#
#
# Artículo 19 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 86 m²
# Descripcion: Piso de 89 m² en venta, de 2 dormit
#
#
# Artículo 20 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 3 baños
# 260 m²
# Terraza
# Piscina
# Descripcion: VILLA DE LUJO CON MATERIALES DE ALT
#
#
# Artículo 21 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 54 m²
# Ascensor
# Descripcion: Piso de 54 m² en venta situado en l
#
#
# Artículo 22 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 80 m²
# Bajos
# Parking
# Descripcion: ***EXPERCASA PATERNA*** Les present
#
#
# Artículo 23 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 3 baños
# 291 m²
# Parking
# Terraza
# Descripcion: Sobre una parcela de algo mas de 50
#
#
# Artículo 24 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 2 baños
# 297 m²
# Parking
# Terraza
# Descripcion: Con una excelente ubicación y una
#
#
# Artículo 25 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 105 m²
# Entresuelo
# Terraza
# Descripcion: *** SENYERA INMOBILIARIA *** pone e
#
#
# Artículo 26 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 6 habs.
# 3 baños
# 359 m²
# Parking
# Terraza
# Descripcion: Sobre una parcela de más de 1.000m2
#
#
# Artículo 27 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 90 m²
# 3ª Planta
# Ascensor
# Descripcion: Piso en Venta en Quart de Poblet -
#
#
# Artículo 28 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 102 m²
# Ascensor
# Descripcion: Piso de segunda mano en venta situa
#
#
# Artículo 29 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 100 m²
# Ascensor
# Balcón
# Descripcion: Particulares venden piso muy lumino
#
#
# Artículo 30 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 100 m²
# Terraza
# Descripcion: BAJO DE CASA en venta en Paterna en
#
#
# No se encontró el articulo re-CardPackMinimal--qualitySeal
#
# >>>>>>>>>>>>>> fotocasa11.txt <<<<<<<<<<<<<<
# -------------> Procesando clase: re-CardPackMinimal, total artículos encontrados: 30
# Artículo 1 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 3 baños
# 154 m²
# 3ª Planta
# Ascensor
# Descripcion: **** SENYERA INMOBILIARIA **** pone
#
#
# Artículo 2 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 136 m²
# Terraza
# Balcón
# Descripcion: Piso totalmente reformado.  Cocina
#
#
# Artículo 3 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 90 m²
# 1ª Planta
# Ascensor
# Descripcion: ¡Luminoso y espacioso piso en venta
#
#
# Artículo 4 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 132 m²
# Terraza
# Descripcion: Ponemos a su disposición esta encan
#
#
# Artículo 5 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 210 m²
# Parking
# Terraza
# Descripcion: Se vende casa en Manises, una joya
#
#
# Artículo 6 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 4 baños
# 220 m²
# Parking
# Terraza
# Descripcion: UBICACIÓN APROXIMADA. De particular
#
#
# Artículo 7 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 120 m²
# Ascensor
# Balcón
# Descripcion: Preguntar por Sra Regina
# Telefeno
#
#
# Artículo 8 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 113 m²
# 1ª Planta
# Ascensor
# Descripcion: Este encantador piso en Aldaia es p
#
#
# Artículo 9 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 89 m²
# 4ª Planta
# Balcón
# Descripcion: Estupendo piso en Paterna, zona de
#
#
# Artículo 10 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 4 baños
# 333 m²
# Parking
# Terraza
# Descripcion: Este magnífico chalet independiente
#
#
# Artículo 11 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 7 habs.
# 3 baños
# 344 m²
# Terraza
# Piscina
# Descripcion: "Grupo Inmobiliario Selling House t
#
#
# Artículo 12 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 98 m²
# Parking
# Descripcion: OPORTUNIDAD EN LA MEJOR ZONA DE PAT
#
#
# Artículo 13 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 135 m²
# 3ª Planta
# Ascensor
# Descripcion: Os presentamos este precioso ático
#
#
# Artículo 14 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 4 baños
# 550 m²
# Parking
# Piscina
# Descripcion: Bienvenidos a este impresionante ch
#
#
# Artículo 15 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 103 m²
# Bajos
# Ascensor
# Descripcion: os presentamos esta vivienda semi-n
#
#
# Artículo 16 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 285 m²
# 2ª Planta
# Terraza
# Descripcion: Vivienda de estilo señorial con toq
#
#
# Artículo 17 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 120 m²
# Parking
# Terraza
# Descripcion: JTM Dreams les presenta esta fantás
#
#
# Artículo 18 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 88 m²
# 3ª Planta
# Ascensor
# Descripcion: Ponemos a su disposición este lumin
#
#
# Artículo 19 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 4 baños
# 333 m²
# Parking
# Terraza
# Descripcion: Sus grandes cristales y sus espacio
#
#
# Artículo 20 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 2 baños
# 216 m²
# Parking
# Terraza
# Descripcion: CASA EN VENTA CON PISCINA COMUN EN
#
#
# Artículo 21 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 79 m²
# Balcón
# Descripcion: Inmobiliaria Inmobanco, les present
#
#
# Artículo 22 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 85 m²
# Descripcion: INCREIBLE VIVIENDA REFORMADA JUNTO
#
#
# Artículo 23 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 73 m²
# Descripcion: gran oportunidad junto al mercado l
#
#
# Artículo 24 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 70 m²
# Descripcion: Piso en cuarta altura sin ascensor,
#
#
# Artículo 25 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 1 hab.
# 2 baños
# 100 m²
# 2ª Planta
# Ascensor
# Descripcion: ¡No dejes pasar la oportunidad de v
#
#
# Artículo 26 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 4 baños
# 219 m²
# Parking
# Terraza
# Descripcion: Diseño que acapara todas las mirada
#
#
# Artículo 27 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 6 habs.
# 3 baños
# 318 m²
# Parking
# Terraza
# Descripcion: Unifamiliar con excelentes calidade
#
#
# Artículo 28 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 160 m²
# Parking
# Piscina
# Descripcion: Nov Real Estate presenta este chale
#
#
# Artículo 29 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 2 baños
# 179 m²
# Parking
# Terraza
# Descripcion: Este impresionante chalet se sitúa
#
#
# Artículo 30 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 93 m²
# 3ª Planta
# Balcón
# Descripcion: Ponemos a su disposición  en el cor
#
#
# -------------> Procesando clase: re-CardPackMinimal--qualitySeal, total artículos encontrados: 8
# Artículo 1 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 132 m²
# Terraza
# Descripcion: Ponemos a su disposición esta encan
#
#
# Artículo 2 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 285 m²
# 2ª Planta
# Terraza
# Descripcion: Vivienda de estilo señorial con toq
#
#
# Artículo 3 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 88 m²
# 3ª Planta
# Ascensor
# Descripcion: Ponemos a su disposición este lumin
#
#
# Artículo 4 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 4 baños
# 333 m²
# Parking
# Terraza
# Descripcion: Sus grandes cristales y sus espacio
#
#
# Artículo 5 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 4 baños
# 219 m²
# Parking
# Terraza
# Descripcion: Diseño que acapara todas las mirada
#
#
# Artículo 6 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 6 habs.
# 3 baños
# 318 m²
# Parking
# Terraza
# Descripcion: Unifamiliar con excelentes calidade
#
#
# Artículo 7 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 2 baños
# 179 m²
# Parking
# Terraza
# Descripcion: Este impresionante chalet se sitúa
#
#
# Artículo 8 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 93 m²
# 3ª Planta
# Balcón
# Descripcion: Ponemos a su disposición  en el cor
#
#
#
# >>>>>>>>>>>>>> fotocasa12.txt <<<<<<<<<<<<<<
# -------------> Procesando clase: re-CardPackMinimal, total artículos encontrados: 30
# Artículo 1 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 1 hab.
# 1 baño
# 70 m²
# 3ª Planta
# Ascensor
# Descripcion: REF: PAT-11
#
# Tecnocasa Nou Moles ve
#
#
# Artículo 2 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 85 m²
# Bajos
# Ascensor
# Descripcion: PISOS del LEVANTE dispone en exclus
#
#
# Artículo 3 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 111 m²
# Ascensor
# Balcón
# Descripcion: (Particular sin intermediarios  pre
#
#
# Artículo 4 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 baños
# 310 m²
# 3ª Planta
# Ascensor
# Parking
# Descripcion: LOFT OFICINA EN VENTA MUY LUMINOSA
#
#
# Artículo 5 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 3 baños
# 242 m²
# Parking
# Terraza
# Descripcion: Esta es una oportunidad excepcional
#
#
# Artículo 6 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 60 m²
# 2ª Planta
# Balcón
# Descripcion: PISOS del LEVANTE dispone en exclus
#
#
# Artículo 7 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 78 m²
# 2ª Planta
# Ascensor
# Descripcion: PISOS del LEVANTE dispone en exclus
#
#
# Artículo 8 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 3 baños
# 279 m²
# Parking
# Terraza
# Descripcion: Chalet con 476 metros de parcela y
#
#
# Artículo 9 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 160 m²
# Parking
# Terraza
# Descripcion: Se vende una preciosa casa situada
#
#
# Artículo 10 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 164 m²
# 5ª Planta
# Ascensor
# Descripcion: INMOBILIARIA LA AVENIDA TE TRAE EST
#
#
# Artículo 11 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 140 m²
# Descripcion: Particular vende Magnifico Duplex d
#
#
# Artículo 12 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 3 baños
# 160 m²
# Parking
# Piscina
# Descripcion: Chalet en El Plantío (Paterna)
#
# Ubi
#
#
# Artículo 13 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 2 baños
# 160 m²
# 3ª Planta
# Ascensor
# Descripcion: 008MIN189. ÁTICO SEMINUEVO Y AMPLIO
#
#
# Artículo 14 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 3 baños
# 291 m²
# Parking
# Terraza
# Descripcion: ¡Descubre tu hogar ideal en El Plan
#
#
# Artículo 15 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 106 m²
# Balcón
# Calefacción
# Descripcion: se vende piso en Aldaia, bien ubica
#
#
# Artículo 16 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 200 m²
# Parking
# Terraza
# Descripcion: JTM Dreams les presenta este fantás
#
#
# Artículo 17 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 84 m²
# 1ª Planta
# Terraza
# Descripcion: TURIA HOMES:
#
# Acogedora Vivienda Un
#
#
# Artículo 18 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 117 m²
# 3ª Planta
# Ascensor
# Descripcion: " " " " "Grupo Inmobiliario Selling
#
#
# Artículo 19 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 100 m²
# Ascensor
# Parking
# Descripcion: Piso en planta baja con ascensor, d
#
#
# Artículo 20 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 122 m²
# Ascensor
# Balcón
# Descripcion: Se vende piso en Manises, Valencia.
#
#
# Artículo 21 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 87 m²
# Ascensor
# Balcón
# Descripcion: ¡Oportunidad única en el centro de
#
#
# Artículo 22 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 145 m²
# Ascensor
# Balcón
# Descripcion: Particular vende piso. Todo exterio
#
#
# Artículo 23 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 129 m²
# Terraza
# Descripcion: MIES INMOBILIARIA VENDE EN EXCLUSIV
#
#
# Artículo 24 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 2 baños
# 161 m²
# 3ª Planta
# Ascensor
# Descripcion: 008MIN189. ÁTICO SEMINUEVO Y AMPLIO
#
#
# Artículo 25 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 64 m²
# Descripcion: Excelente vivienda  muy luminosa  z
#
#
# Artículo 26 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 4 baños
# 219 m²
# Parking
# Terraza
# Descripcion: Situada en una parcela de 809 m² y
#
#
# Artículo 27 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 74 m²
# 3ª Planta
# Ascensor
# Descripcion: ¡Te presentamos esta encantadora vi
#
#
# Artículo 28 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 116 m²
# 5ª Planta
# Ascensor
# Descripcion: Presentamos un magnífico ático en e
#
#
# Artículo 29 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 9 habs.
# 4 baños
# 321 m²
# Terraza
# Balcón
# Descripcion: Esta excepcional casa se encuentra
#
#
# Artículo 30 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 117 m²
# 2ª Planta
# Ascensor
# Descripcion: Vertecasa les ofrece está vivienda
#
#
# -------------> Procesando clase: re-CardPackMinimal--qualitySeal, total artículos encontrados: 5
# Artículo 1 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 3 baños
# 279 m²
# Parking
# Terraza
# Descripcion: Chalet con 476 metros de parcela y
#
#
# Artículo 2 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 2 baños
# 160 m²
# 3ª Planta
# Ascensor
# Descripcion: 008MIN189. ÁTICO SEMINUEVO Y AMPLIO
#
#
# Artículo 3 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 2 baños
# 161 m²
# 3ª Planta
# Ascensor
# Descripcion: 008MIN189. ÁTICO SEMINUEVO Y AMPLIO
#
#
# Artículo 4 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 74 m²
# 3ª Planta
# Ascensor
# Descripcion: ¡Te presentamos esta encantadora vi
#
#
# Artículo 5 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 116 m²
# 5ª Planta
# Ascensor
# Descripcion: Presentamos un magnífico ático en e
#
#
#
# >>>>>>>>>>>>>> fotocasa13.txt <<<<<<<<<<<<<<
# -------------> Procesando clase: re-CardPackMinimal, total artículos encontrados: 30
# Artículo 1 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 101 m²
# Descripcion: Inmueble EN CESION DE REMATE. Oport
#
#
# Artículo 2 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 111 m²
# Ascensor
# Parking
# Descripcion: ¡¡¡ ABSTENERSE INMOBILIARIAS !!!!
# A
#
#
# Artículo 3 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 108 m²
# 1ª Planta
# Ascensor
# Descripcion: Si estás buscando un hogar cómodo,
#
#
# Artículo 4 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 4 baños
# 428 m²
# Parking
# Terraza
# Descripcion: Serenidad, confort y amplios espaci
#
#
# Artículo 5 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 112 m²
# 3ª Planta
# Ascensor
# Descripcion: INMOBILIARIA PRIMERA AVENIDA te ofr
#
#
# Artículo 6 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 2 baños
# 120 m²
# Ascensor
# Parking
# Descripcion: Ático duplex para entrar a vivir. P
#
#
# Artículo 7 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 111 m²
# 5ª Planta
# Ascensor
#
#
# Artículo 8 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 72 m²
# 5ª Planta
# Balcón
# Descripcion: 007RBO109 EXTERIOR CON BALCÓN JUNTO
#
#
# Artículo 9 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 117 m²
# 5ª Planta
# Ascensor
#
#
# Artículo 10 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 109 m²
# 7ª Planta
# Ascensor
#
#
# Artículo 11 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 72 m²
# Balcón
# Calefacción
# Descripcion: ¡SIN COMISIÓN DEL COMPRADOR! Este c
#
#
# Artículo 12 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 132 m²
# Ascensor
# Terraza
# Descripcion: Moderno y Luminoso  Ático Duplex en
#
#
# Artículo 13 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 95 m²
# 1ª Planta
# Ascensor
# Descripcion: PISOS del LEVANTE dispone en exclus
#
#
# Artículo 14 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 3 baños
# 140 m²
# Parking
# Piscina
# Descripcion: Particular vende excelente chalet s
#
#
# Artículo 15 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 115 m²
# Ascensor
# Parking
# Descripcion: ¡¡Excelente piso en Paterna!!
#
# UBIC
#
#
# Artículo 16 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 90 m²
# Terraza
# Calefacción
# Descripcion: 002DMA260  CASA SEMIREFORMADA CON 2
#
#
# Artículo 17 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 89 m²
# Terraza
# Calefacción
# Descripcion: 002DMA260  CASA SEMIREFORMADA CON 2
#
#
# Artículo 18 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 1 hab.
# 1 baño
# 47 m²
# Bajos
# Ascensor
# Descripcion: Actualmente, la vivienda está alqui
#
#
# Artículo 19 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 134 m²
# 1ª Planta
# Ascensor
# Descripcion: Ponemos a su disposición piso ubica
#
#
# Artículo 20 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 114 m²
# 2ª Planta
# Ascensor
# Descripcion: SOLO INVERSORES. Exenta de IVA e IT
#
#
# Artículo 21 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 114 m²
# Ascensor
# Terraza
#
#
# Artículo 22 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 131 m²
# 1ª Planta
# Ascensor
# Descripcion: Este magnífico piso en la mejor zon
#
#
# Artículo 23 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 3 baños
# 136 m²
# Descripcion: Se ofrece esta magnífica propiedad,
#
#
# Artículo 24 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 1 hab.
# 1 baño
# 63 m²
# Bajos
# Ascensor
# Descripcion: Actualmente, la propiedad está alqu
#
#
# Artículo 25 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 113 m²
# 2ª Planta
# Ascensor
# Descripcion: 008PDI190. AMPLIO ÁTICO SEMINUEVO C
#
#
# Artículo 26 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 113 m²
# 2ª Planta
# Ascensor
# Descripcion: 008PDI190. AMPLIO ÁTICO SEMINUEVO C
#
#
# Artículo 27 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 112 m²
# 2ª Planta
# Ascensor
# Descripcion: 008PDI190. AMPLIO ÁTICO SEMINUEVO C
#
#
# Artículo 28 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 329 m²
# Parking
# Terraza
# Descripcion: ART INMOBILIARIA gestiona la VENTA
#
#
# Artículo 29 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 140 m²
# 3ª Planta
# Ascensor
# Descripcion: ESPECTACULAR DÚPLEX CON GARAJE Y TR
#
#
# Artículo 30 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 143 m²
# Terraza
# Piscina
# Calefacción
# Descripcion: Presentamos este maravilloso chalet
#
#
# -------------> Procesando clase: re-CardPackMinimal--qualitySeal, total artículos encontrados: 9
# Artículo 1 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 72 m²
# 5ª Planta
# Balcón
# Descripcion: 007RBO109 EXTERIOR CON BALCÓN JUNTO
#
#
# Artículo 2 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 90 m²
# Terraza
# Calefacción
# Descripcion: 002DMA260  CASA SEMIREFORMADA CON 2
#
#
# Artículo 3 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 89 m²
# Terraza
# Calefacción
# Descripcion: 002DMA260  CASA SEMIREFORMADA CON 2
#
#
# Artículo 4 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 1 hab.
# 1 baño
# 47 m²
# Bajos
# Ascensor
# Descripcion: Actualmente, la vivienda está alqui
#
#
# Artículo 5 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 134 m²
# 1ª Planta
# Ascensor
# Descripcion: Ponemos a su disposición piso ubica
#
#
# Artículo 6 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 1 hab.
# 1 baño
# 63 m²
# Bajos
# Ascensor
# Descripcion: Actualmente, la propiedad está alqu
#
#
# Artículo 7 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 113 m²
# 2ª Planta
# Ascensor
# Descripcion: 008PDI190. AMPLIO ÁTICO SEMINUEVO C
#
#
# Artículo 8 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 113 m²
# 2ª Planta
# Ascensor
# Descripcion: 008PDI190. AMPLIO ÁTICO SEMINUEVO C
#
#
# Artículo 9 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 112 m²
# 2ª Planta
# Ascensor
# Descripcion: 008PDI190. AMPLIO ÁTICO SEMINUEVO C
#
#
#
# >>>>>>>>>>>>>> fotocasa14.txt <<<<<<<<<<<<<<
# -------------> Procesando clase: re-CardPackMinimal, total artículos encontrados: 24
# Artículo 1 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 73 m²
# Terraza
# Calefacción
# Descripcion: Chalet céntrico.
# Dos cómodas estanc
#
#
# Artículo 2 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 2 baños
# 120 m²
# 6ª Planta
# Ascensor
# Descripcion: Dúplex luminoso y funcional con exc
#
#
# Artículo 3 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 115 m²
# 2ª Planta
# Ascensor
# Descripcion: ¡Descubre tu nuevo hogar en el cora
#
#
# Artículo 4 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 100 m²
# 4ª Planta
# Ascensor
# Descripcion: Espectacular vivienda en el BARRIO
#
#
# Artículo 5 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 98 m²
# Terraza
# Balcón
# Descripcion: GIMENO ASESORES ofrece esta casa en
#
#
# Artículo 6 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 58 m²
# 4ª Planta
# Balcón
# Descripcion: +INMOPLAZA ALBAL++ Te ofrece este E
#
#
# Artículo 7 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 115 m²
# Ascensor
# Descripcion: REF 2535 Se vende amplia vivienda c
#
#
# Artículo 8 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 190 m²
# Bajos
# Ascensor
# Descripcion: Venta de Atico Duplex en zona muy p
#
#
# Artículo 9 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 90 m²
# 5ª Planta
# Ascensor
# Descripcion: Venta de piso en Paterna, zona Aven
#
#
# Artículo 10 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 187 m²
# Parking
# Terraza
# Descripcion: Casa  en MANISES-CENTRO, con 187 m²
#
#
# Artículo 11 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 1 hab.
# 1 baño
# 49 m²
# 3ª Planta
# Ascensor
# Descripcion: Venta de piso en finca recien const
#
#
# Artículo 12 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 2 baños
# 359 m²
# Parking
# Terraza
# Descripcion: Mr. Wesell presenta:
#
#  Estupendo c
#
#
# Artículo 13 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 1 hab.
# 1 baño
# 200 m²
# Bajos
# Parking
# Descripcion: Disponible en OKHOME.
#
# Magnífico l
#
#
# Artículo 14 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 6 habs.
# 1 baño
# 326 m²
# Terraza
# Descripcion: REF.VENTA  de casa en zona centro d
#
#
# Artículo 15 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 2 baños
# 88 m²
# 7ª Planta
# Ascensor
#
#
# Artículo 16 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 2 baños
# 95 m²
# 7ª Planta
# Ascensor
#
#
# Artículo 17 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 1 hab.
# 1 baño
# 64 m²
# 5ª Planta
# Ascensor
#
#
# Artículo 18 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 77 m²
# Ascensor
# Terraza
#
#
# Artículo 19 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 147 m²
# 1ª Planta
# Ascensor
# Descripcion: Piso en venta en la zona Centro de
#
#
# Artículo 20 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 86 m²
# 3ª Planta
# Calefacción
# Descripcion: Piso con reforma A ESTRENAR en el c
#
#
# Artículo 21 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 131 m²
# 1ª Planta
# Ascensor
#
#
# Artículo 22 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 4 baños
# 237 m²
# Parking
# Piscina
#
#
# Artículo 23 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 1 baño
# 230 m²
# Parking
# Terraza
# Descripcion: Casa en muy buena zona superficie t
#
#
# Artículo 24 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 2 baños
# 831 m²
# Parking
# Terraza
# Descripcion: Esta magnífica villa en venta en Pa
#
#
# -------------> Procesando clase: re-CardPackMinimal--qualitySeal, total artículos encontrados: 1
# Artículo 1 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 86 m²
# 3ª Planta
# Calefacción
# Descripcion: Piso con reforma A ESTRENAR en el c
#
#
#
# >>>>>>>>>>>>>> fotocasa15.txt <<<<<<<<<<<<<<
# No se encontró el articulo re-CardPackMinimal
# No se encontró el articulo re-CardPackMinimal--qualitySeal
#
# >>>>>>>>>>>>>> fotocasa16.txt <<<<<<<<<<<<<<
# No se encontró el articulo re-CardPackMinimal
# No se encontró el articulo re-CardPackMinimal--qualitySeal
#
# >>>>>>>>>>>>>> fotocasa2.txt <<<<<<<<<<<<<<
# -------------> Procesando clase: re-CardPackMinimal, total artículos encontrados: 30
# Artículo 1 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 292 m²
# Descripcion: Casa Independiente de 300 metros, 4
#
#
# Artículo 2 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 136 m²
# Ascensor
# Descripcion: Esta propiedad está OCUPADA por ter
#
#
# Artículo 3 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 3 baños
# 203 m²
# Descripcion: chalet independiente en residencial
#
#
# Artículo 4 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 85 m²
# Descripcion: CASA SITUADO EN ZONA CENTRO DE QUAR
#
#
# Artículo 5 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 1 hab.
# 1 baño
# 60 m²
# 4ª Planta
# Balcón
# Descripcion: ATENCIÓN inversores o particulares!
#
#
# Artículo 6 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 3 baños
# 200 m²
# Parking
# Terraza
# Descripcion: ¡Descubre el hogar de tus sueños en
#
#
# Artículo 7 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 150 m²
# Ascensor
# Terraza
# Descripcion: Descubre este adorable ático dúplex
#
#
# Artículo 8 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 77 m²
# Balcón
# Calefacción
# Descripcion: Este piso en venta en Paterna se en
#
#
# Artículo 9 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 110 m²
# 2ª Planta
# Ascensor
# Descripcion: Piso Amplio y Reformado en Manises:
#
#
# Artículo 10 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 6 habs.
# 4 baños
# 550 m²
# Terraza
# Piscina
# Descripcion: Excelente Chalet independiente en L
#
#
# Artículo 11 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 3 baños
# 100 m²
# 1ª Planta
# Ascensor
# Descripcion: OKHOME pone  a su disposición una e
#
#
# Artículo 12 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 77 m²
# Balcón
# Calefacción
# Descripcion: Este piso en venta en Paterna se en
#
#
# Artículo 13 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 4 baños
# 170 m²
# Parking
# Terraza
# Descripcion: Creaespacio Residencial presenta es
#
#
# Artículo 14 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 85 m²
# 4ª Planta
# Terraza
# Descripcion: ¡Déjate cautivar por esta joya reci
#
#
# Artículo 15 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 2 baños
# 247 m²
# Parking
# Terraza
# Descripcion: ¡Descubre el hogar de tus sueños en
#
#
# Artículo 16 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 347 m²
# Parking
# Terraza
# Descripcion: Las sensaciones no se pueden transm
#
#
# Artículo 17 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 115 m²
# 2ª Planta
# Calefacción
# Descripcion: Disponible en OKHOME. Espectacular
#
#
# Artículo 18 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 105 m²
# Parking
# Terraza
# Descripcion: Este encantador chalet en La Cañada
#
#
# Artículo 19 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 2 baños
# 220 m²
# Parking
# Terraza
# Descripcion: .
#  Estas deseando vivir en la urba
#
#
# Artículo 20 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 79 m²
# 4ª Planta
# Balcón
# Descripcion: PISO CON ARRENDATARIOS.  IDEAL INVE
#
#
# Artículo 21 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 121 m²
# 2ª Planta
# Ascensor
# Descripcion: OPORTUNIDAD: SEMINUEVO CON GARAJE Y
#
#
# Artículo 22 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 2 baños
# 216 m²
# Parking
# Terraza
# Descripcion: ¡Descubre tu nuevo hogar en la excl
#
#
# Artículo 23 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 150 m²
# Ascensor
# Parking
# Descripcion: Bienvenidos a este encantador dúple
#
#
# Artículo 24 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 69 m²
# 5ª Planta
# Balcón
# Descripcion: ¡Atención inversores! PISO CON INQU
#
#
# Artículo 25 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 162 m²
# Parking
# Terraza
# Descripcion: Una oportunidad única para reforman
#
#
# Artículo 26 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 6 habs.
# 3 baños
# 315 m²
# Parking
# Terraza
# Descripcion: Oportunidad única en el corazón del
#
#
# Artículo 27 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 110 m²
# Terraza
# Aire acondicionado
# Descripcion: Ven a descubrir lugares que esconde
#
#
# Artículo 28 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 87 m²
# Bajos
# Terraza
# Descripcion: Disponemos de un bajo vivienda en A
#
#
# Artículo 29 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 65 m²
# Ascensor
# Terraza
# Descripcion: Manises! , desde 185.000 euros, Áti
#
#
# Artículo 30 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 150 m²
# Parking
# Terraza
# Descripcion: Chalet ideal para vivir todo el año
#
#
# No se encontró el articulo re-CardPackMinimal--qualitySeal
#
# >>>>>>>>>>>>>> fotocasa3.txt <<<<<<<<<<<<<<
# -------------> Procesando clase: re-CardPackMinimal, total artículos encontrados: 30
# Artículo 1 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 63 m²
# Descripcion: Piso en el municipio de Manises, pr
#
#
# Artículo 2 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 104 m²
# Descripcion: Oportunidad sólo para inversores. E
#
#
# Artículo 3 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 101 m²
# Descripcion: Oportunidad sólo para inversores. E
#
#
# Artículo 4 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 62 m²
# Descripcion: Oportunidad sólo para inversores. E
#
#
# Artículo 5 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 1 hab.
# 1 baño
# 58 m²
# Ascensor
# Descripcion: ¿Buscas tu nuevo hogar en Paterna?
#
#
# Artículo 6 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 150 m²
# Ascensor
# Terraza
# Descripcion: Presentamos a la venta éste excelen
#
#
# Artículo 7 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 90 m²
# 1ª Planta
# Ascensor
# Descripcion: **************ATENCION VIVIENDA SIN
#
#
# Artículo 8 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 77 m²
# 2ª Planta
# Ascensor
# Descripcion: *** CON OCUPANTES ILEGALES **
#
# NO S
#
#
# Artículo 9 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 161 m²
# Descripcion: Piso en Quart de Poblet. Cuenta con
#
#
# Artículo 10 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 57 m²
# Descripcion: Valorado en:  160.000 €
# Consíguelo
#
#
# Artículo 11 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 89 m²
# Descripcion: Valorado en:  160.000 €
# Consíguelo
#
#
# Artículo 12 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 78 m²
# Descripcion: Valorado en:  160.000 €
# Consíguelo
#
#
# Artículo 13 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 103 m²
# Descripcion: Valorado en: 149.238 €
# Consíguelo e
#
#
# Artículo 14 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 48 m²
# Descripcion: Valorado en:  160.000 €
# Consíguelo
#
#
# Artículo 15 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 89 m²
# Descripcion: Valorado en:  160.000 €
# Consíguelo
#
#
# Artículo 16 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 91 m²
# Descripcion: Valorado en: 152.274
# Consíguelo en
#
#
# Artículo 17 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 103 m²
# Descripcion: Valorado en: 167.213
# Consíguelo en
#
#
# Artículo 18 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 98 m²
# Descripcion: Valorado en:  157.795
# Consíguelo en
#
#
# Artículo 19 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 161 m²
# Descripcion: Valorado en: 157.836 €
# Consíguelo e
#
#
# Artículo 20 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 116 m²
# Descripcion: Valorado en: 159.081 €
# Consíguelo
#
#
# Artículo 21 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 56 m²
# Descripcion: Valorado en:  160.000 €
# Consíguelo
#
#
# Artículo 22 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 114 m²
# Descripcion: Valorado en: 245.138 €
# Consíguelo e
#
#
# Artículo 23 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 86 m²
# Descripcion: Valorado en:  160.000 €
# Consíguelo
#
#
# Artículo 24 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 75 m²
# Descripcion: Valorado en:  160.000 €
# Consíguelo
#
#
# Artículo 25 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 700 m²
# Terraza
# Descripcion: ************LA VIVIENDA SE VENDE CO
#
#
# Artículo 26 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 71 m²
# 4ª Planta
# Balcón
# Descripcion: *****ATENCION************
#
# ********
#
#
# Artículo 27 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 63 m²
# 2ª Planta
# Ascensor
# Descripcion: Vivienda en Quart de Poblet, en edi
#
#
# Artículo 28 de la clase re-CardPackMinimal...
# ...
#
#
# Artículo 14 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 4 baños
# 237 m²
# Parking
# Terraza
# Descripcion: CASA INDEPENDIENTE DE OBRA NUEVA EN
#
#
# Artículo 15 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 79 m²
# Descripcion: ¡Gran Oportunidad de Inversión en S
#
#
# Artículo 16 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 1 hab.
# 1 baño
# 21 m²
# Descripcion: ¡Gran Oportunidad de Inversión en S
#
#
# Artículo 17 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 64 m²
# Descripcion: INMUEBLE  EN VENTA -
#  “Esta propied
#
#
# Artículo 18 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 150 m²
# 3ª Planta
# Ascensor
# Descripcion: Referencia del inmueble 7653 ATICO
#
#
# Artículo 19 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 150 m²
# Terraza
# Descripcion: Caseta con parcela, situada en zona
#
#
# Artículo 20 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 1 m²
# Descripcion: Piso situado en la planta de altura
#
#
# Artículo 21 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 3 baños
# 400 m²
# Parking
# Terraza
# Descripcion: ¡Descubre la oportunidad de tu vida
#
#
# Artículo 22 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 4 baños
# 540 m²
# Parking
# Terraza
# Descripcion: Espectacular residencia sita en la
#
#
# Artículo 23 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 1 m²
# Descripcion: Piso situado en la planta de altura
#
#
# Artículo 24 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 130 m²
# Parking
# Terraza
# Descripcion: —NO INMOBILIARIAS LEER—Estupendo ch
#
#
# Artículo 25 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 252 m²
# Parking
# Terraza
# Descripcion: Se vende casa de pueblo, muy bien c
#
#
# Artículo 26 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 78 m²
# 2ª Planta
# Descripcion: Inmon . Vende piso en Manises a 3 m
#
#
# Artículo 27 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 3 baños
# 460 m²
# Parking
# Terraza
# Descripcion: Es un chalet seminuevo con Cocina i
#
#
# Artículo 28 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 3 baños
# 207 m²
# Parking
# Terraza
# Descripcion: OBRA NUEVA en La Cañada, Valencia
# ¡
#
#
# Artículo 29 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 6 habs.
# 3 baños
# 723 m²
# Parking
# Terraza
# Descripcion: Esta bonita propiedad cuenta con un
#
#
# Artículo 30 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 56 m²
# Descripcion: Leer más
#
#
# -------------> Procesando clase: re-CardPackMinimal--qualitySeal, total artículos encontrados: 1
# Artículo 1 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 160 m²
# Parking
# Terraza
# Descripcion: Esta es una oportunidad excepcional
#
#
#
# >>>>>>>>>>>>>> fotocasa8.txt <<<<<<<<<<<<<<
# -------------> Procesando clase: re-CardPackMinimal, total artículos encontrados: 30
# Artículo 1 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 1 baño
# 167 m²
# Parking
# Terraza
# Descripcion: Casa solar en venta en la zona Cent
#
#
# Artículo 2 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 153 m²
# Terraza
# Descripcion: 002RRQ250  Hazla a tu gusto con TER
#
#
# Artículo 3 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 52 m²
# 2ª Planta
# Descripcion: ¡Oportunidad única de adquirir tu h
#
#
# Artículo 4 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 189 m²
# Descripcion: Casa Cueva en venta en Paterna. Se
#
#
# Artículo 5 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 2 baños
# 297 m²
# Parking
# Terraza
# Descripcion: Con una excelente ubicación y una
#
#
# Artículo 6 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 1 m²
# Descripcion: <strong>I</strong><strong>NMUEBLE P
#
#
# Artículo 7 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 baños
# 193 m²
# Terraza
# Descripcion: ****EXPERCASA PATERNA****Dispone de
#
#
# Artículo 8 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 105 m²
# Parking
# Terraza
# Descripcion: ¡Descubre la casa adosada de tus su
#
#
# Artículo 9 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 98 m²
# Terraza
# Calefacción
# Descripcion: Ahora si que has encontrado la vivi
#
#
# Artículo 10 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 77 m²
# Descripcion: *INMUEBLE EN VENTA EN ALBORGÍ, (PAT
#
#
# Artículo 11 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 3 baños
# 220 m²
# Parking
# Terraza
# Descripcion: Excelente chalet cerca del centro y
#
#
# Artículo 12 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 154 m²
# Terraza
# Descripcion: 002RRQ250  Hazla a tu gusto con TER
#
#
# Artículo 13 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 6 habs.
# 3 baños
# 320 m²
# Parking
# Terraza
# Descripcion: Bienvenidos, soy una elegante y exc
#
#
# Artículo 14 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 3 baños
# 279 m²
# Parking
# Terraza
# Descripcion: Confortable vivienda situada frente
#
#
# Artículo 15 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 96 m²
# Ascensor
# Descripcion: Excelente piso de cuatro dormitorio
#
#
# Artículo 16 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 113 m²
# Terraza
# Piscina
# Descripcion: CHALET PARA ENTRAR A VIVIR EN VENTA
#
#
# Artículo 17 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 69 m²
# 4ª Planta
# Aire acondicionado
# Descripcion: ¡Descubre tu nuevo hogar en Manises
#
#
# Artículo 18 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 142 m²
# Parking
# Terraza
# Descripcion: EXPERCASA QUART DE POBLET presenta
#
#
# Artículo 19 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 224 m²
# Terraza
# Aire acondicionado
# Descripcion: ***EXPERCASA PATERNA**** LES PRESEN
#
#
# Artículo 20 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 6 habs.
# 2 baños
# 180 m²
# Terraza
# Piscina
# Descripcion: ¡Descubre tu nuevo hogar en Villama
#
#
# Artículo 21 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 79 m²
# 1ª Planta
# Descripcion: SIN COMISION INMOBILIARIA. Vivienda
#
#
# Artículo 22 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 69 m²
# 1ª Planta
# Descripcion: ******NO SE PUEDE VISITAR******
#
# SI
#
#
# Artículo 23 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 170 m²
# Piscina
# Aire acondicionado
# Descripcion: ¡Oportunidad única!
#
# Chalet indepe
#
#
# Artículo 24 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 2 baños
# 216 m²
# Parking
# Terraza
# Descripcion: Descubre esta espectacular oportuni
#
#
# Artículo 25 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 62 m²
# Descripcion: Oportunidad sólo para inversores. E
#
#
# Artículo 26 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 160 m²
# Parking
# Terraza
# Descripcion: CASA DE VENTA DE 3 HABITACIONES CON
#
#
# Artículo 27 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 120 m²
# 4ª Planta
# Ascensor
# Descripcion: Leer más
#
#
# Artículo 28 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 72 m²
# Aire acondicionado
# Descripcion: tarspso Local a pie de calle en ple
#
#
# Artículo 29 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 265 m²
# Parking
# Terraza
# Descripcion: Disponemos en EXCLUSIVA  de una CAS
#
#
# Artículo 30 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 307 m²
# Terraza
# Piscina
# Descripcion: ATHIKA presenta como novedad. Fabul
#
#
# -------------> Procesando clase: re-CardPackMinimal--qualitySeal, total artículos encontrados: 3
# Artículo 1 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 153 m²
# Terraza
# Descripcion: 002RRQ250  Hazla a tu gusto con TER
#
#
# Artículo 2 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 98 m²
# Terraza
# Calefacción
# Descripcion: Ahora si que has encontrado la vivi
#
#
# Artículo 3 de la clase re-CardPackMinimal--qualitySeal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 154 m²
# Terraza
# Descripcion: 002RRQ250  Hazla a tu gusto con TER
#
#
#
# >>>>>>>>>>>>>> fotocasa9.txt <<<<<<<<<<<<<<
# -------------> Procesando clase: re-CardPackMinimal, total artículos encontrados: 30
# Artículo 1 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 64 m²
# 5ª Planta
# Balcón
# Descripcion: REF 5933 piso en Manises en zona El
#
#
# Artículo 2 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 6 habs.
# 4 baños
# 550 m²
# Parking
# Terraza
# Descripcion: Sobre una parcela de mas de 2200m2
#
#
# Artículo 3 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 100 m²
# Aire acondicionado
# Descripcion: ¡Descubre tu nuevo hogar en este en
#
#
# Artículo 4 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 78 m²
# Terraza
# Calefacción
# Descripcion: Agencia Mediterránea tiene el place
#
#
# Artículo 5 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 3 baños
# 202 m²
# Parking
# Terraza
# Descripcion: ENTER PROPERTIES os presenta este c
#
#
# Artículo 6 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 160 m²
# Parking
# Terraza
# Descripcion: ¡Bienvenidos a este bonito chalet e
#
#
# Artículo 7 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 1 hab.
# 1 baño
# 85 m²
# Ascensor
# Terraza
# Descripcion: Loft-Oficina en planta 1ª  con asce
#
#
# Artículo 8 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 120 m²
# 1ª Planta
# Terraza
# Descripcion: JTM Dreams les presenta esta fantás
#
#
# Artículo 9 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 88 m²
# Terraza
# Calefacción
# Descripcion: Athika presenta. Finca rustica con
#
#
# Artículo 10 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 64 m²
# 5ª Planta
# Balcón
# Descripcion: ¡Oportunidad en venta! Piso en el c
#
#
# Artículo 11 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 120 m²
# 1ª Planta
# Terraza
# Descripcion: Este encantador piso de 4 dormitori
#
#
# Artículo 12 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 96 m²
# 1ª Planta
# Balcón
# Descripcion: ARKIA Inmuebles & Arquitectura te o
#
#
# Artículo 13 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 90 m²
# Bajos
# Terraza
# Descripcion: Vivienda en planta baja en edificio
#
#
# Artículo 14 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 98 m²
# 3ª Planta
# Ascensor
# Descripcion: Piso de 3 habitaciones, dos cuartos
#
#
# Artículo 15 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 5 baños
# 586 m²
# Parking
# Terraza
# Descripcion: Vivienda de espacios amplios distri
#
#
# Artículo 16 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 48 m²
# 3ª Planta
# Calefacción
# Descripcion: En venta con un buen inquilino, ide
#
#
# Artículo 17 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 3 baños
# 452 m²
# Parking
# Terraza
# Descripcion: En venta magnífico chalet independi
#
#
# Artículo 18 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 2 baños
# 216 m²
# Parking
# Terraza
# Descripcion: Vivienda adosada en La Cañada, ubic
#
#
# Artículo 19 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 86 m²
# Descripcion: Piso de 89 m² en venta, de 2 dormit
#
#
# Artículo 20 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 3 baños
# 260 m²
# Terraza
# Piscina
# Descripcion: VILLA DE LUJO CON MATERIALES DE ALT
#
#
# Artículo 21 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 54 m²
# Ascensor
# Descripcion: Piso de 54 m² en venta situado en l
#
#
# Artículo 22 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 2 habs.
# 1 baño
# 80 m²
# Bajos
# Parking
# Descripcion: ***EXPERCASA PATERNA*** Les present
#
#
# Artículo 23 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 3 baños
# 291 m²
# Parking
# Terraza
# Descripcion: Sobre una parcela de algo mas de 50
#
#
# Artículo 24 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 5 habs.
# 2 baños
# 297 m²
# Parking
# Terraza
# Descripcion: Con una excelente ubicación y una
#
#
# Artículo 25 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 2 baños
# 105 m²
# Entresuelo
# Terraza
# Descripcion: *** SENYERA INMOBILIARIA *** pone e
#
#
# Artículo 26 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 6 habs.
# 3 baños
# 359 m²
# Parking
# Terraza
# Descripcion: Sobre una parcela de más de 1.000m2
#
#
# Artículo 27 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 3 habs.
# 1 baño
# 90 m²
# 3ª Planta
# Ascensor
# Descripcion: Piso en Venta en Quart de Poblet -
#
#
# Artículo 28 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 2 baños
# 102 m²
# Ascensor
# Descripcion: Piso de segunda mano en venta situa
#
#
# Artículo 29 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 100 m²
# Ascensor
# Balcón
# Descripcion: Particulares venden piso muy lumino
#
#
# Artículo 30 de la clase re-CardPackMinimal...
# Info container: re-CardPackMinimal-info-container
# 4 habs.
# 1 baño
# 100 m²
# Terraza
# Descripcion: BAJO DE CASA en venta en Paterna en
#
#
# No se encontró el articulo re-CardPackMinimal--qualitySeal
# (447, 13)
#                     calle     barrio municipio tipo_vivienda  \
# 0  Piso en venta en Quart  de Poblet   Manises          Piso
# 1           Piso en venta  en Aldaia   Manises          Piso
#
#                              titulo  habitaciones  metros_cuadrados  aseos  \
# 0  Piso en venta en Quart de Poblet           2.0              80.0    2.0
# 1           Piso en venta en Aldaia           3.0             150.0    2.0
#
#       planta                                        descripcion  \
# 0       None  REF 2534 Se vende  magnifica vivienda seminuev...
# 1  3ª Planta  Piso  en ALDAIA - BARRIO DEL CRISTO, con 150 m...
#
#              etiquetas garaje    precio
# 0  [Ascensor, Terraza]     No  195000.0
# 1           [Ascensor]     No  190000.0

# %% [markdown]
# #### Nos vamos a asegurar de que no **existen duplicados**, ya que hay muchos anuncios repetidos en la plataforma. Nos basaremos en específicas columnas importantes, ya que algunas son tipo lista y dan problemas a la hora de usar ***.drop_duplicates()***

# %%
print(f"Antes de eliminar duplicados: {fotocasa2.shape}")
fotocasa2 = fotocasa2.drop_duplicates(subset=['tipo_vivienda','habitaciones', 'metros_cuadrados', 'aseos', 'planta', 'garaje', 'precio'])
print(f"Después de eliminar duplicados: {fotocasa2.shape}")
# Out:
# Antes de eliminar duplicados: (447, 13)
# Después de eliminar duplicados: (323, 13)

# %%
fotocasa2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 323 entries, 0 to 413
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   calle             323 non-null    object
#  1   barrio            323 non-null    object
#  2   municipio         323 non-null    object
#  3   tipo_vivienda     323 non-null    object
#  4   titulo            323 non-null    object
#  5   habitaciones      270 non-null    float64
#  6   metros_cuadrados  322 non-null    float64
#  7   aseos             282 non-null    float64
#  8   planta            89 non-null     object
#  9   descripcion       313 non-null    object
#  10  etiquetas         323 non-null    object
#  11  garaje            323 non-null    object
#  12  precio            321 non-null    float64
# dtypes: float64(4), object(9)
# memory usage: 35.3+ KB

# %% [markdown]
# ### Una vez scrappeadas las 2 partes de fotocasa, **concatenamos** los dataframes y **exportamos a CSV**

# %%
fotocasa = pd.concat([fotocasa1, fotocasa2], ignore_index=True)

# %%
fotocasa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   calle             385 non-null    object
#  1   barrio            385 non-null    object
#  2   municipio         385 non-null    object
#  3   tipo_vivienda     385 non-null    object
#  4   titulo            385 non-null    object
#  5   habitaciones      326 non-null    float64
#  6   metros_cuadrados  384 non-null    float64
#  7   aseos             339 non-null    float64
#  8   planta            94 non-null     object
#  9   descripcion       375 non-null    object
#  10  etiquetas         385 non-null    object
#  11  garaje            385 non-null    object
#  12  precio            383 non-null    float64
# dtypes: float64(4), object(9)
# memory usage: 39.2+ KB

# %%
fotocasa.to_csv("../data/procesado/viviendasFotoCasa.csv", index=True)
